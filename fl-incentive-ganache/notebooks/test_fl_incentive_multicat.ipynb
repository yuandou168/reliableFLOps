# %%
import random
import json
import time
from web3 import Web3
from solcx import compile_standard, install_solc
from web3.exceptions import ContractLogicError, BadFunctionCallOutput
########################################################################
# 0) Setup & Reproducible Random
########################################################################
# Set a fixed seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

########################################################################
# Connect to Ganache & Basic Setup
########################################################################
GANACHE_URL = "http://127.0.0.1:8545"
w3 = Web3(Web3.HTTPProvider(GANACHE_URL))
assert w3.is_connected(), "Could not connect to Ganache"

accounts = w3.eth.accounts
publisher = accounts[0]

# Define deployment parameters
deadline_seconds = 60  # 10 minutes from now

U = 99  # attempt U "user"
# We'll attempt 15 "users" (some fail). At least 11 accounts are needed for 15 attempts.
# If you launched Ganache with `ganache -a 20` or similar, you have enough. For example:
possible_users = accounts[1:U+1]  # U+1 attempts
print(f"Publisher: {publisher}")
print(f"Attempting participants: {possible_users}")
# Out:
# Publisher: 0xAcA7d2813dA5FF0146429803c4FcB8F5c4086DE3
# Attempting participants: ['0x85bD17E7a0B9C96dc14470c69d9CeE6617F83aaB', '0x8E6670a1E36Ba00Bc2b21B6687C54447616A48Ef', '0x557598fd2fC58542f34C88746b1A479Ba3d1d753', '0x6653DBeDd9546a8B6c510778caC65b4474A21949', '0xB3c82BFAb7b450f1B13752071e6AaaB18b84556D', '0xC37D7889ad62de4Fc5798EC7A6fc8dfE6764BBDB', '0x92942835078BbFa9D68A7106aaE6d61a7EB557a2', '0x1cF8d0dA1062975273bBF853b8Aa3221CeF61608', '0xCA1368eFE9b8aE916368F1cA229283a712C0Cd26', '0x658b64D0B8faA91c81A353a11bdbB258cF3E4cAb', '0x7F728dFEA7FE0db60C7f664F5D96c077535e4dBf', '0x3bC80Dd91EF7dD35f8F6CDa6Ea5dEcd2eAF29679', '0xaE45f58c7c27020c341153A5caCFd6dA295d510D', '0x1af38d7bB2de936107ca004c24f5D62E3ac194FF', '0xd7C918590253605939367FC34c499932fDEEEF10', '0x213AAB4B4752921E933E1B118B27d4167b903292', '0x89022b2e9CbA63b7c6F1AeF5E8b83d1F92896f9F', '0xC4a76b530Ff27A469AA2fEd90f43057e8AE065B1', '0xD8EeD91e800c88D017722Fd575fED348E611C844', '0xBaeF5dB9044638E3A689dd6a03C0B2F3e0666cEa', '0xB49B0a1808c7a91934907836DAB637243cE4cF50', '0xd02Af983AE3d6DFB629d59d2C575b132fc8F9e5f', '0x3df3415de141d3488722D4142705A710dd9f2110', '0x8885218f6EAC369D7f212dFa5c734E95F6479777', '0x42E240fBC699d3317Ad5CAE37eBA891EFec04533', '0xE4aBD739c898534a5e505Ba3DEe13B47ACAC85F8', '0xD706C2C792c50d6caB33121385fCE904a6B0DF3A', '0x86B75C7Af0504E8B7c5B647D7BF7d2Fe714B9c34', '0xfd71BFeE615336700447069489A52Bc81Be63f0D', '0x687f1E5f43F4Eb53a40D03a79209DcdD3d31C560', '0xCe9b5AEA6CB4C72B436c5beF48271CE9cD20BEa5', '0xAaf813541E16FB099B97f6a7D42f4A387289431F', '0xd17b086EB6998a65053121507ee9a8eC4871ca51', '0x6072A2a56e1985090365211C36B364182Ca2095B', '0x63dd50a0f611752d44082EafEB46810B569425D4', '0x5A362d5b3fc39EB3262b7a36b68E07fb661Af049', '0xbBEA49B113cF2903d58274A6C5DcD35563b5b41F', '0x0C8174c241cDb42059FAF9Ad7e128605A3AAa15C', '0x971b53629599dcAE598f0A043649671E87a9C848', '0xe705925701E7967B51100f622a80EeaFf57F3962', '0xdeDb34f9Cfdf5491C802A9b65e2dAffaa6B731Ac', '0xEe78444f161B29b2f8133b672c4e77CB7E011B18', '0xb50d3dFc1AcFbBa21f8F1fbaa05d75Be163cEF64', '0xD220d8Cb830871744169c8b18B12eFE8b1BC3A8e', '0x98bb8D480bb5ca5fe7877355A407bea7f8D0cED1', '0x81A9F67d2FB3ACDB391AbdA8215dbDa7B91f8c2f', '0xa6f3dB8B631Cd8Dfd5a3E77854A363333c12cB01', '0xB4577599bFB26d3AE3178efD6012B91978ca65cC', '0x325aA4Acf101b5e16CD083C85707e3BDE1ff1B21', '0x7E426c8808c806A40F2656ef9aeE33Ec869319e9', '0xEfAcdE426DC0F6c51Ed44bF5C7858A0DC5A91791', '0x59dC9ec0582567d1233d90daCFF9A99318272390', '0xcAd363F36bBCF6135619716f7881d2D5D3eea8a7', '0xEDFA8d0c9BBaCEb42729A90eE7095e6fC145112f', '0xE3714EB0B670724c088C13B3Ac3E0DddD1284b86', '0xA11ACE199ADd4e06F136647e0a90D9f9aBF508A7', '0x6Fc47a6846c036745fA4f5bF048DD0d54B5a14c2', '0xb818388CcC895762A9e6320bCbcCbC92976a980D', '0x98b1f617BcA0940765434EA49e908eAEB7bBee0E', '0x2Ef8Ab1D5462FD4d92911f23722Bd0A8e632587b', '0x024BB884Ec537fc7Ac51531deC7fEd147c785651', '0x048778E2156b80E890EBeEC6172019D72c276387', '0x11BFd4F699f5499F795d1c9D719A738340F47B0E', '0xB73F0e10732D4fdab0d4005F6c62C6c6E1fC778e', '0x9BB4B29618C52DC6D40407A81B9217d257f7cf32', '0x5E915df8F75bf9B89F480244768C1BBaFcC4ce46', '0x41E81Bfb7a16D1c5d56642cbaF3c604402D85b08', '0x79ABE7701681578AFF8B2B3873CA383Bce9eb57B', '0x0639D6bd0B9b2D4a6aca7C307021a8BFc6039813', '0x783e5cFDE037fa9D3ED85134A8a6D680277401D0', '0xb60B6eFB1223cC150c29729C8D219176c8bf627c', '0x727c657AaED4601E4752569BB15A5dFdFA3c8aCB', '0x9268D29386aC3A71478C68bc75E0Da36Ef6491ba', '0xF145a46Fc3dC2be4C0c2d8Cc5A7322DC21346eed', '0x080B0af419abdFD5266586fa02dd2d22986c5Dc7', '0x332b68EC03f2D6b09cCFa6627aCBB3c7355B1A0A', '0x027a643B4441252dBC369150C3dA41023Fca150f', '0x6de11E13507d6242456A79d8F2EE2CE21B3812EF', '0x5dc0a482b7524e9D5B7E837f5D663e6EA79c0C08', '0x149DDCE6eBB34DdCB2EcCF63101Cf289EBC6b173', '0x87F1DE2664A2e64303e9Cc1CCE36348B36f18331', '0x38036af98cDE43C417D226827EFCfD74F4AEDA65', '0x1d4FF3FABDCEcde6063a5e4d808078244517F17E', '0xF1dd3e475de4707B7D4676B5bd49591738AfE132', '0xdE836d62E2d0e10F9dA0de1EF0378493d4A25a81', '0x819a269eec277715A39CF500D7d1502e2Cd7203f', '0xD5bc924761Dd62f ...

# %%
########################################################################
# 1) Compile the FLIncentiveMultiCat contract
########################################################################
with open("../contracts/FLIncentiveMultiCat.sol", "r") as f:
    contract_source_code = f.read()
# 2) Install the required version of solc
install_solc('0.8.17')

# 3) Compile using solcx
#    The compile_standard function expects a specific JSON format.
compiled_sol = compile_standard(
    {
        "language": "Solidity",
        "sources": {
            "FLIncentiveMultiCat.sol": {"content": contract_source_code}
        },
        "settings": {
            "outputSelection": {
                "*": {
                    "*": ["metadata", "evm.bytecode", "evm.deployedBytecode", "abi"]
                }
            }
        }
    },
    solc_version="0.8.17",
)

contract_info = compiled_sol["contracts"]["FLIncentiveMultiCat.sol"]["FLIncentiveMultiCat"]
abi = contract_info["abi"]
bytecode = contract_info["evm"]["bytecode"]["object"]

print("Contract compiled successfully.\n")
# Out:
# Contract compiled successfully.

# %%
# ---------------------------------------------------------------------
# 3) Deploy the Contract
# ---------------------------------------------------------------------

# Create contract object
contract = w3.eth.contract(abi=abi, bytecode=bytecode)

# Define deployment parameters
deadline_seconds = 100  # 10 minutes from now
deadline_timestamp = int(time.time()) + deadline_seconds
reward_pool_eth = 10  # 10 ETH as the reward pool

# Build deployment transaction
deploy_txn = contract.constructor(deadline_timestamp).build_transaction({
    "from": publisher,
    "value": w3.to_wei(reward_pool_eth, "ether"),  # 10 ETH in Wei
    "nonce": w3.eth.get_transaction_count(publisher),
    # "gas": 5000000,  # Adjusted Gas Limit
    "gasPrice": w3.to_wei("1", "gwei"),
})

# Sign and send the deployment transaction
try:
    # Since Ganache automatically unlocks accounts, no need to sign manually
    deploy_hash = w3.eth.send_transaction(deploy_txn)
    print("Deploying contract...")
    deploy_receipt = w3.eth.wait_for_transaction_receipt(deploy_hash)
    
    # Check deployment status
    if deploy_receipt.status != 1:
        print("Contract deployment failed.")
        # Optionally, attempt to extract revert reason
        # revert_reason = get_revert_reason(deploy_hash)
        # print(f"Revert Reason: {revert_reason}")
    else:
        print("Contract deployed successfully.")
    
    # Retrieve contract address
    contract_address = deploy_receipt.contractAddress
    if not contract_address:
        print("Failed to retrieve contract address.")
        exit(1)
    else:
        print(f"Contract deployed at address: {contract_address}\n")
    
    # Initialize contract instance
    contract_instance = w3.eth.contract(address=contract_address, abi=abi)
    
    # Fetch and display deadline information
    on_chain_deadline = contract_instance.functions.deadline().call()
    current_time = int(time.time())
    time_until_deadline = on_chain_deadline - current_time
    print(f"On-chain deadline: {on_chain_deadline} (current time: {current_time})")
    print(f"Time until deadline: {time_until_deadline} seconds\n")

except ContractLogicError as e:
    print(f"ContractLogicError during deployment: {e}")
except BadFunctionCallOutput as e:
    print(f"BadFunctionCallOutput during deployment: {e}")
except Exception as e:
    print(f"An unexpected error occurred during deployment: {e}")
    exit(1)
# Out:
# Deploying contract...
# Contract deployed successfully.
# Contract deployed at address: 0xf5E9131bb41A4c85fd498cBC081d4DabEd2ef532
#
# On-chain deadline: 1737569144 (current time: 1737569044)
# Time until deadline: 100 seconds

# %%
########################################################################
# 3) Assign Scenarios to All Users
########################################################################
# Define probability thresholds as constants
# INVALID_SYNERGY_PROB = 0.1       # 10% chance
# INCORRECT_STAKE_PROB = 0.2       # 20% chance (0.2 <= r < 0.4)
# FORCED_LATE_JOIN_PROB = 0.2      # 20% chance (0.4 <= r < 0.5)
# NORMAL_SUCCESS_PROB = 0.5         # 50% chance (r >= 0.5)

INVALID_SYNERGY_PROB = 0.       # 10% chance
INCORRECT_STAKE_PROB = 0.       # 20% chance (0.2 <= r < 0.4)
FORCED_LATE_JOIN_PROB = 0.      # 10% chance (0.4 <= r < 0.5)
NORMAL_SUCCESS_PROB = 1.         # 60% chance (r >= 0.6)

def random_cat_in_range() -> int:
    """
    Returns a valid data/resource category [0, 1, 2].
    0 = Low, 1 = Medium, 2 = High
    """
    return random.randint(0, 2)

def random_cat_out_of_range() -> int:
    """
    Returns an invalid category (3), expected to cause the transaction to revert.
    """
    return 3

def determine_scenario(r: float) -> str:
    """
    Determines the join attempt scenario based on the random value r.
    
    Parameters:
        r (float): A random float between 0 and 1.
    
    Returns:
        str: The scenario name.
    """
    if r < INVALID_SYNERGY_PROB:
        return "Invalid Synergy"
    elif r < INVALID_SYNERGY_PROB + INCORRECT_STAKE_PROB:
        return "Incorrect Stake"
    elif r < INVALID_SYNERGY_PROB + INCORRECT_STAKE_PROB + FORCED_LATE_JOIN_PROB:
        return "Forced Late Join"
    else:
        return "Normal Success"

def get_combo_params(dcat: int, rcat: int) -> tuple:
    """
    Fetches the stake required and reward multiplier for the given data and resource categories.
    
    Parameters:
        dcat (int): Data category (0=Low, 1=Medium, 2=High)
        rcat (int): Resource category (0=Low, 1=Medium, 2=High)
    
    Returns:
        tuple: (stakeRequired, rewardMultiplier)
    """
    return contract_instance.functions.getComboParams(dcat, rcat).call()

# Assign scenarios to all users
user_scenarios = []
for acct in possible_users:
    r = random.random()
    scenario = determine_scenario(r)
    
    if scenario == "Invalid Synergy":
        dcat = random_cat_in_range()
        rcat = random_cat_out_of_range()
    elif scenario == "Incorrect Stake":
        dcat = random_cat_in_range()
        rcat = random_cat_in_range()
    elif scenario == "Forced Late Join":
        dcat = random_cat_in_range()
        rcat = random_cat_in_range()
    else:  # "Normal Success"
        dcat = random_cat_in_range()
        rcat = random_cat_in_range()
    
    synergy_info = (dcat, rcat)
    user_scenarios.append({
        "address": acct,
        "scenario": scenario,
        "synergy": synergy_info
    })

########################################################################
# 4) Separate Users into Groups Based on Scenario
########################################################################
# Group users by scenario
normal_success_users = []
invalid_synergy_users = []
incorrect_stake_users = []
forced_late_join_users = []

for user in user_scenarios:
    if user["scenario"] == "Normal Success":
        normal_success_users.append(user)
    elif user["scenario"] == "Invalid Synergy":
        invalid_synergy_users.append(user)
    elif user["scenario"] == "Incorrect Stake":
        incorrect_stake_users.append(user)
    elif user["scenario"] == "Forced Late Join":
        forced_late_join_users.append(user)

# Initialize lists to track outcomes
successful_users = []
fail_reasons = []

# %%
########################################################################
# 5) Process Normal Success, Invalid Synergy, and Incorrect Stake Attempts
########################################################################
print("Processing Normal Success, Invalid Synergy, and Incorrect Stake join attempts...\n")

for i, user in enumerate(normal_success_users + invalid_synergy_users + incorrect_stake_users, start=1):
    acct = user["address"]
    scenario = user["scenario"]
    synergy_info = user["synergy"]
    dcat, rcat = synergy_info
    
    print(f"User Attempt {i}: Scenario={scenario}, Synergy={synergy_info}")
    
    try:
        # Fetch required stake from the contract; may revert if synergy is invalid
        stake_req, _ = get_combo_params(dcat, rcat)
        
        # Modify stake if the scenario is "Incorrect Stake"
        if scenario == "Incorrect Stake":
            stake_req = stake_req // 2 if stake_req > 0 else 1  # Halve the stake or set to 1 Wei
        
        # For "Normal Success" and "Invalid Synergy", no time manipulation is needed
        # Build the join transaction
        join_txn = contract_instance.functions.join(dcat, rcat).build_transaction({
            "from": acct,
            "value": stake_req,
            "nonce": w3.eth.get_transaction_count(acct),
            "gas": 3_000_000,
            "gasPrice": w3.to_wei("1", "gwei"),
        })
        
        # Send the transaction
        j_hash = w3.eth.send_transaction(join_txn)
        j_receipt = w3.eth.wait_for_transaction_receipt(j_hash)
        
        # After transaction is mined, verify if the participant joined successfully
        part_data = contract_instance.functions.participants(acct).call()
        joined_status = part_data[0]
        
        if joined_status:
            # Append to successful_users with relevant details
            successful_users.append({
                "address": acct,
                "synergy": synergy_info,
                "scenario": scenario,
                "stake": stake_req
            })
            print(f"  SUCCESS: Joined successfully with synergy {synergy_info}, Stake={stake_req} Wei.\n")
        else:
            # If `joined` is False, log as a failure
            fail_reasons.append({
                "address": acct,
                "synergy": synergy_info,
                "scenario": scenario,
                "reason": "Transaction did not set joined=True"
            })
            print(f"  FAIL: Transaction did not set joined=True.\n")
    
    except Exception as e:
        # Log any exceptions as failures with error messages
        fail_reasons.append({
            "address": acct,
            "synergy": synergy_info,
            "scenario": scenario,
            "reason": str(e)
        })
        print(f"  FAIL: Error occurred - {str(e)[:100]}...\n")
# Out:
# Processing Normal Success, Invalid Synergy, and Incorrect Stake join attempts...
#
# User Attempt 1: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 2: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 3: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 4: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 5: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 6: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 7: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 8: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 9: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 10: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 11: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 12: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 13: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 14: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 15: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 16: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 17: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 18: Scenario=Normal Success, Synergy=(1, 2)
#   SUCCESS: Joined successfully with synergy (1, 2), Stake=3500000000000000000 Wei.
#
# User Attempt 19: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 20: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 21: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 22: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 23: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 24: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 25: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 26: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 27: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 28: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 29: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 30: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 31: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 32: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 33: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 34: Scenario=Normal Success, Synergy=(1, 2)
#   SUCCESS: Joined successfully with synergy (1, 2), Stake=3500000000000000000 Wei.
#
# User Attempt 35: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 36: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 37: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 38: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 39: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 40: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 41: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 42: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 43: Scenario=Normal Success, Synergy=(1, 2)
#   SUCCESS: Joined successfully with synergy (1, 2), Stake=3500000000000000000 Wei.
#
# User Attempt 44: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 45: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 46: Scenario=Normal Success, Synergy=(1, 2)
#   SUCCESS: Joined successfully with synergy (1, 2), Stake=3500000000000000000 Wei.
#
# User Attempt 47: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 48: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 49: Scenario=Normal Success, Synergy=(1, 2)
#   SUCCESS: Joined successfully with synergy (1, 2), Stake=3500000000000000000 Wei.
#
# User Attempt 50: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 51: Scenario=Normal Success, Synergy=(1, 2)
#   SUCCESS: Joined successfully with synergy (1, 2), Stake=3500000000000000000 Wei.
#
# User Attempt 52: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 53: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 54: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 55: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 56: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 57: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 58: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 59: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 60: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 61: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 62: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 63: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 64: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 65: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 66: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 67: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 68: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 69: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 70: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 71: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 72: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 73: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 74: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 75: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 76: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.
#
# User Attempt 77: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 78: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 79: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 80: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 81: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 82: Scenario=Normal Success, Synergy=(2, 1)
#   SUCCESS: Joined successfully with synergy (2, 1), Stake=3000000000000000000 Wei.
#
# User Attempt 83: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 84: Scenario=Normal Success, Synergy=(0, 1)
#   SUCCESS: Joined successfully with synergy (0, 1), Stake=2000000000000000000 Wei.
#
# User Attempt 85: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 86: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 87: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 88: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 89: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 90: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 91: Scenario=Normal Success, Synergy=(1, 1)
#   SUCCESS: Joined successfully with synergy (1, 1), Stake=2500000000000000000 Wei.
#
# User Attempt 92: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 93: Scenario=Normal Success, Synergy=(1, 0)
#   SUCCESS: Joined successfully with synergy (1, 0), Stake=1500000000000000000 Wei.
#
# User Attempt 94: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 95: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 96: Scenario=Normal Success, Synergy=(0, 0)
#   SUCCESS: Joined successfully with synergy (0, 0), Stake=1000000000000000000 Wei.
#
# User Attempt 97: Scenario=Normal Success, Synergy=(2, 2)
#   SUCCESS: Joined successfully with synergy (2, 2), Stake=4000000000000000000 Wei.
#
# User Attempt 98: Scenario=Normal Success, Synergy=(2, 0)
#   SUCCESS: Joined successfully with synergy (2, 0), Stake=2000000000000000000 Wei.
#
# User Attempt 99: Scenario=Normal Success, Synergy=(0, 2)
#   SUCCESS: Joined successfully with synergy (0, 2), Stake=3000000000000000000 Wei.

# %%
########################################################################
# 6) Process Forced Late Join Attempts
########################################################################
if forced_late_join_users:
    print("Processing Forced Late Join attempts by advancing blockchain time...\n")
    
    # Calculate total time to advance to pass the deadline
    on_chain_deadline = contract_instance.functions.deadline().call()
    current_ts = w3.eth.get_block("latest")["timestamp"]
    leftover = on_chain_deadline - current_ts
    
    if leftover > 0:
        # Advance time by the leftover plus an extra second to ensure deadline is passed
        time_to_add = leftover + 1
        print(f"Advancing blockchain time by {time_to_add} seconds to pass deadline.")
        
        # Increase blockchain time
        w3.provider.make_request('evm_increaseTime', [time_to_add])
        
        # Mine a new block to apply the time change
        w3.provider.make_request('evm_mine', [])
        print(f"Blockchain time advanced by {time_to_add} seconds.\n")
    else:
        print("Deadline has already passed.\n")
    
    for i, user in enumerate(forced_late_join_users, start=1):
        acct = user["address"]
        scenario = user["scenario"]
        synergy_info = user["synergy"]
        dcat, rcat = synergy_info
        
        print(f"Forced Late Join Attempt {i}: Scenario={scenario}, Synergy={synergy_info}")
        
        try:
            # Fetch required stake from the contract
            stake_req, _ = get_combo_params(dcat, rcat)
            
            # No stake modification needed for Forced Late Join
            # Build the join transaction
            join_txn = contract_instance.functions.join(dcat, rcat).build_transaction({
                "from": acct,
                "value": stake_req,
                "nonce": w3.eth.get_transaction_count(acct),
                "gas": 3_000_000,
                "gasPrice": w3.to_wei("1", "gwei"),
            })
            
            # Send the transaction
            j_hash = w3.eth.send_transaction(join_txn)
            j_receipt = w3.eth.wait_for_transaction_receipt(j_hash)
            
            # After transaction is mined, verify if the participant joined successfully
            part_data = contract_instance.functions.participants(acct).call()
            joined_status = part_data[0]
            
            if joined_status:
                # Append to successful_users with relevant details
                successful_users.append({
                    "address": acct,
                    "synergy": synergy_info,
                    "scenario": scenario,
                    "stake": stake_req
                })
                print(f"  SUCCESS: Joined successfully with synergy {synergy_info}, Stake={stake_req} Wei.\n")
            else:
                # If `joined` is False, log as a failure
                fail_reasons.append({
                    "address": acct,
                    "synergy": synergy_info,
                    "scenario": scenario,
                    "reason": "Transaction did not set joined=True"
                })
                print(f"  FAIL: Transaction did not set joined=True.\n")
        
        except Exception as e:
            # Log any exceptions as failures with error messages
            fail_reasons.append({
                "address": acct,
                "synergy": synergy_info,
                "scenario": scenario,
                "reason": str(e)
            })
            print(f"  FAIL: Error occurred - {str(e)[:100]}...\n")

# %%
########################################################################
# 7) Finalize the Contract to Distribute Rewards
########################################################################
print("Finalizing the contract to distribute rewards...\n")

try:
    # Build the finalize transaction
    finalize_txn = contract_instance.functions.finalize().build_transaction({
        "from": publisher,
        "nonce": w3.eth.get_transaction_count(publisher),
        "gas": 3_000_000,
        "gasPrice": w3.to_wei("1", "gwei"),
    })
    
    # Send the finalize transaction
    finalize_hash = w3.eth.send_transaction(finalize_txn)
    finalize_receipt = w3.eth.wait_for_transaction_receipt(finalize_hash)
    
    print("Contract has been finalized and rewards distributed.\n")
    
except Exception as e:
    print(f"FAIL: Finalize failed - {str(e)[:100]}...\n")

########################################################################
# 8) Summary of Join Attempts
########################################################################
print("Summary of Join Attempts:")
print("===================================")

print("\nSuccessful Participants:")
for idx, user in enumerate(successful_users, start=1):
    print(f"{idx}. Address: {user['address']}")
    print(f"   Scenario: {user['scenario']}")
    print(f"   Synergy: DataCat={user['synergy'][0]}, ResourceCat={user['synergy'][1]}")
    print(f"   Stake Paid: {user['stake']} Wei\n")

print("\nFailed Attempts:")
for idx, failure in enumerate(fail_reasons, start=1):
    print(f"{idx}. Address: {failure['address']}")
    print(f"   Scenario: {failure['scenario']}")
    print(f"   Synergy Attempted: DataCat={failure['synergy'][0]}, ResourceCat={failure['synergy'][1]}")
    print(f"   Reason: {failure['reason']}\n")
# Out:
# Finalizing the contract to distribute rewards...
#
# Contract has been finalized and rewards distributed.
#
# Summary of Join Attempts:
# ===================================
#
# Successful Participants:
# 1. Address: 0x85bD17E7a0B9C96dc14470c69d9CeE6617F83aaB
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 2. Address: 0x8E6670a1E36Ba00Bc2b21B6687C54447616A48Ef
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 3. Address: 0x557598fd2fC58542f34C88746b1A479Ba3d1d753
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 4. Address: 0x6653DBeDd9546a8B6c510778caC65b4474A21949
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 5. Address: 0xB3c82BFAb7b450f1B13752071e6AaaB18b84556D
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 6. Address: 0xC37D7889ad62de4Fc5798EC7A6fc8dfE6764BBDB
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 7. Address: 0x92942835078BbFa9D68A7106aaE6d61a7EB557a2
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 8. Address: 0x1cF8d0dA1062975273bBF853b8Aa3221CeF61608
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 9. Address: 0xCA1368eFE9b8aE916368F1cA229283a712C0Cd26
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 10. Address: 0x658b64D0B8faA91c81A353a11bdbB258cF3E4cAb
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 11. Address: 0x7F728dFEA7FE0db60C7f664F5D96c077535e4dBf
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 12. Address: 0x3bC80Dd91EF7dD35f8F6CDa6Ea5dEcd2eAF29679
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 13. Address: 0xaE45f58c7c27020c341153A5caCFd6dA295d510D
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 14. Address: 0x1af38d7bB2de936107ca004c24f5D62E3ac194FF
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 15. Address: 0xd7C918590253605939367FC34c499932fDEEEF10
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 16. Address: 0x213AAB4B4752921E933E1B118B27d4167b903292
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 17. Address: 0x89022b2e9CbA63b7c6F1AeF5E8b83d1F92896f9F
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 18. Address: 0xC4a76b530Ff27A469AA2fEd90f43057e8AE065B1
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 19. Address: 0xD8EeD91e800c88D017722Fd575fED348E611C844
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 20. Address: 0xBaeF5dB9044638E3A689dd6a03C0B2F3e0666cEa
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 21. Address: 0xB49B0a1808c7a91934907836DAB637243cE4cF50
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 22. Address: 0xd02Af983AE3d6DFB629d59d2C575b132fc8F9e5f
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 23. Address: 0x3df3415de141d3488722D4142705A710dd9f2110
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 24. Address: 0x8885218f6EAC369D7f212dFa5c734E95F6479777
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 25. Address: 0x42E240fBC699d3317Ad5CAE37eBA891EFec04533
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 26. Address: 0xE4aBD739c898534a5e505Ba3DEe13B47ACAC85F8
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 27. Address: 0xD706C2C792c50d6caB33121385fCE904a6B0DF3A
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 28. Address: 0x86B75C7Af0504E8B7c5B647D7BF7d2Fe714B9c34
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 29. Address: 0xfd71BFeE615336700447069489A52Bc81Be63f0D
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 30. Address: 0x687f1E5f43F4Eb53a40D03a79209DcdD3d31C560
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 31. Address: 0xCe9b5AEA6CB4C72B436c5beF48271CE9cD20BEa5
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 32. Address: 0xAaf813541E16FB099B97f6a7D42f4A387289431F
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 33. Address: 0xd17b086EB6998a65053121507ee9a8eC4871ca51
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 34. Address: 0x6072A2a56e1985090365211C36B364182Ca2095B
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 35. Address: 0x63dd50a0f611752d44082EafEB46810B569425D4
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 36. Address: 0x5A362d5b3fc39EB3262b7a36b68E07fb661Af049
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 37. Address: 0xbBEA49B113cF2903d58274A6C5DcD35563b5b41F
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 38. Address: 0x0C8174c241cDb42059FAF9Ad7e128605A3AAa15C
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 39. Address: 0x971b53629599dcAE598f0A043649671E87a9C848
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 40. Address: 0xe705925701E7967B51100f622a80EeaFf57F3962
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 41. Address: 0xdeDb34f9Cfdf5491C802A9b65e2dAffaa6B731Ac
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 42. Address: 0xEe78444f161B29b2f8133b672c4e77CB7E011B18
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 43. Address: 0xb50d3dFc1AcFbBa21f8F1fbaa05d75Be163cEF64
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 44. Address: 0xD220d8Cb830871744169c8b18B12eFE8b1BC3A8e
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 45. Address: 0x98bb8D480bb5ca5fe7877355A407bea7f8D0cED1
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 46. Address: 0x81A9F67d2FB3ACDB391AbdA8215dbDa7B91f8c2f
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 47. Address: 0xa6f3dB8B631Cd8Dfd5a3E77854A363333c12cB01
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 48. Address: 0xB4577599bFB26d3AE3178efD6012B91978ca65cC
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 49. Address: 0x325aA4Acf101b5e16CD083C85707e3BDE1ff1B21
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 50. Address: 0x7E426c8808c806A40F2656ef9aeE33Ec869319e9
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 51. Address: 0xEfAcdE426DC0F6c51Ed44bF5C7858A0DC5A91791
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 52. Address: 0x59dC9ec0582567d1233d90daCFF9A99318272390
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 53. Address: 0xcAd363F36bBCF6135619716f7881d2D5D3eea8a7
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 54. Address: 0xEDFA8d0c9BBaCEb42729A90eE7095e6fC145112f
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 55. Address: 0xE3714EB0B670724c088C13B3Ac3E0DddD1284b86
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 56. Address: 0xA11ACE199ADd4e06F136647e0a90D9f9aBF508A7
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 57. Address: 0x6Fc47a6846c036745fA4f5bF048DD0d54B5a14c2
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 58. Address: 0xb818388CcC895762A9e6320bCbcCbC92976a980D
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 59. Address: 0x98b1f617BcA0940765434EA49e908eAEB7bBee0E
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 60. Address: 0x2Ef8Ab1D5462FD4d92911f23722Bd0A8e632587b
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 61. Address: 0x024BB884Ec537fc7Ac51531deC7fEd147c785651
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 62. Address: 0x048778E2156b80E890EBeEC6172019D72c276387
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 63. Address: 0x11BFd4F699f5499F795d1c9D719A738340F47B0E
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 64. Address: 0xB73F0e10732D4fdab0d4005F6c62C6c6E1fC778e
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 65. Address: 0x9BB4B29618C52DC6D40407A81B9217d257f7cf32
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 66. Address: 0x5E915df8F75bf9B89F480244768C1BBaFcC4ce46
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 67. Address: 0x41E81Bfb7a16D1c5d56642cbaF3c604402D85b08
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 68. Address: 0x79ABE7701681578AFF8B2B3873CA383Bce9eb57B
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 69. Address: 0x0639D6bd0B9b2D4a6aca7C307021a8BFc6039813
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 70. Address: 0x783e5cFDE037fa9D3ED85134A8a6D680277401D0
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 71. Address: 0xb60B6eFB1223cC150c29729C8D219176c8bf627c
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 72. Address: 0x727c657AaED4601E4752569BB15A5dFdFA3c8aCB
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 73. Address: 0x9268D29386aC3A71478C68bc75E0Da36Ef6491ba
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 74. Address: 0xF145a46Fc3dC2be4C0c2d8Cc5A7322DC21346eed
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 75. Address: 0x080B0af419abdFD5266586fa02dd2d22986c5Dc7
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 76. Address: 0x332b68EC03f2D6b09cCFa6627aCBB3c7355B1A0A
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 77. Address: 0x027a643B4441252dBC369150C3dA41023Fca150f
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 78. Address: 0x6de11E13507d6242456A79d8F2EE2CE21B3812EF
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 79. Address: 0x5dc0a482b7524e9D5B7E837f5D663e6EA79c0C08
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 80. Address: 0x149DDCE6eBB34DdCB2EcCF63101Cf289EBC6b173
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 81. Address: 0x87F1DE2664A2e64303e9Cc1CCE36348B36f18331
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 82. Address: 0x38036af98cDE43C417D226827EFCfD74F4AEDA65
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 83. Address: 0x1d4FF3FABDCEcde6063a5e4d808078244517F17E
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 84. Address: 0xF1dd3e475de4707B7D4676B5bd49591738AfE132
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 85. Address: 0xdE836d62E2d0e10F9dA0de1EF0378493d4A25a81
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 86. Address: 0x819a269eec277715A39CF500D7d1502e2Cd7203f
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 87. Address: 0xD5bc924761Dd62f0dFE2951E7ED0623A8c4eC6B1
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 88. Address: 0xd9001E3B35429ebF4777aD6157f094F6B8F9cec2
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 89. Address: 0xD50804816860aBa1F13455e1408810909E61F2D5
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 90. Address: 0xBc3b0A7C84E95784C61ACc135b2468C6A22b8F5e
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 91. Address: 0x596a94a6602694ef2f2761921B64d43Dd6E61c68
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 92. Address: 0xa6D82F240d12eF8Ba072F04193f8A595BB677929
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 93. Address: 0x2A60649849502be21375DD299C5fb2e13CB2C0fD
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 94. Address: 0x92Bb7Ad7d065566E1de4CBc78189398A5D4dECCE
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 95. Address: 0xbF1165261ACa9218030Dd7Bd9cec06079Ee5cB8A
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 96. Address: 0xE02D9bE87C1e3BD53cf5B868ad95BDcf78352991
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 97. Address: 0x8A3F3Cb0022154D0fDBeC12f9f3874e9A6ca5118
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 98. Address: 0x96c44720a905DBa08B4D927f1CE5D7E81C9ea134
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 99. Address: 0x0e8c4cAC2962218F65D4FCA61c297f31F83B59E5
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
#
# Failed Attempts:
# Contract has been finalized and rewards distributed.
#
# Summary of Join Attempts:
# ===================================
#
# Successful Participants:
# 1. Address: 0x85bD17E7a0B9C96dc14470c69d9CeE6617F83aaB
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 2. Address: 0x8E6670a1E36Ba00Bc2b21B6687C54447616A48Ef
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 3. Address: 0x557598fd2fC58542f34C88746b1A479Ba3d1d753
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 4. Address: 0x6653DBeDd9546a8B6c510778caC65b4474A21949
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 5. Address: 0xB3c82BFAb7b450f1B13752071e6AaaB18b84556D
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 6. Address: 0xC37D7889ad62de4Fc5798EC7A6fc8dfE6764BBDB
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 7. Address: 0x92942835078BbFa9D68A7106aaE6d61a7EB557a2
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 8. Address: 0x1cF8d0dA1062975273bBF853b8Aa3221CeF61608
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 9. Address: 0xCA1368eFE9b8aE916368F1cA229283a712C0Cd26
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 10. Address: 0x658b64D0B8faA91c81A353a11bdbB258cF3E4cAb
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 11. Address: 0x7F728dFEA7FE0db60C7f664F5D96c077535e4dBf
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 12. Address: 0x3bC80Dd91EF7dD35f8F6CDa6Ea5dEcd2eAF29679
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 13. Address: 0xaE45f58c7c27020c341153A5caCFd6dA295d510D
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 14. Address: 0x1af38d7bB2de936107ca004c24f5D62E3ac194FF
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 15. Address: 0xd7C918590253605939367FC34c499932fDEEEF10
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 16. Address: 0x213AAB4B4752921E933E1B118B27d4167b903292
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 17. Address: 0x89022b2e9CbA63b7c6F1AeF5E8b83d1F92896f9F
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 18. Address: 0xC4a76b530Ff27A469AA2fEd90f43057e8AE065B1
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 19. Address: 0xD8EeD91e800c88D017722Fd575fED348E611C844
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 20. Address: 0xBaeF5dB9044638E3A689dd6a03C0B2F3e0666cEa
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 21. Address: 0xB49B0a1808c7a91934907836DAB637243cE4cF50
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 22. Address: 0xd02Af983AE3d6DFB629d59d2C575b132fc8F9e5f
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 23. Address: 0x3df3415de141d3488722D4142705A710dd9f2110
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 24. Address: 0x8885218f6EAC369D7f212dFa5c734E95F6479777
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 25. Address: 0x42E240fBC699d3317Ad5CAE37eBA891EFec04533
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 26. Address: 0xE4aBD739c898534a5e505Ba3DEe13B47ACAC85F8
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 27. Address: 0xD706C2C792c50d6caB33121385fCE904a6B0DF3A
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 28. Address: 0x86B75C7Af0504E8B7c5B647D7BF7d2Fe714B9c34
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 29. Address: 0xfd71BFeE615336700447069489A52Bc81Be63f0D
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 30. Address: 0x687f1E5f43F4Eb53a40D03a79209DcdD3d31C560
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 31. Address: 0xCe9b5AEA6CB4C72B436c5beF48271CE9cD20BEa5
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 32. Address: 0xAaf813541E16FB099B97f6a7D42f4A387289431F
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 33. Address: 0xd17b086EB6998a65053121507ee9a8eC4871ca51
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 34. Address: 0x6072A2a56e1985090365211C36B364182Ca2095B
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 35. Address: 0x63dd50a0f611752d44082EafEB46810B569425D4
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 36. Address: 0x5A362d5b3fc39EB3262b7a36b68E07fb661Af049
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 37. Address: 0xbBEA49B113cF2903d58274A6C5DcD35563b5b41F
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 38. Address: 0x0C8174c241cDb42059FAF9Ad7e128605A3AAa15C
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 39. Address: 0x971b53629599dcAE598f0A043649671E87a9C848
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 40. Address: 0xe705925701E7967B51100f622a80EeaFf57F3962
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 41. Address: 0xdeDb34f9Cfdf5491C802A9b65e2dAffaa6B731Ac
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 42. Address: 0xEe78444f161B29b2f8133b672c4e77CB7E011B18
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 43. Address: 0xb50d3dFc1AcFbBa21f8F1fbaa05d75Be163cEF64
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 44. Address: 0xD220d8Cb830871744169c8b18B12eFE8b1BC3A8e
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 45. Address: 0x98bb8D480bb5ca5fe7877355A407bea7f8D0cED1
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 46. Address: 0x81A9F67d2FB3ACDB391AbdA8215dbDa7B91f8c2f
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 47. Address: 0xa6f3dB8B631Cd8Dfd5a3E77854A363333c12cB01
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 48. Address: 0xB4577599bFB26d3AE3178efD6012B91978ca65cC
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 49. Address: 0x325aA4Acf101b5e16CD083C85707e3BDE1ff1B21
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 50. Address: 0x7E426c8808c806A40F2656ef9aeE33Ec869319e9
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 51. Address: 0xEfAcdE426DC0F6c51Ed44bF5C7858A0DC5A91791
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=2
#    Stake Paid: 3500000000000000000 Wei
#
# 52. Address: 0x59dC9ec0582567d1233d90daCFF9A99318272390
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 53. Address: 0xcAd363F36bBCF6135619716f7881d2D5D3eea8a7
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 54. Address: 0xEDFA8d0c9BBaCEb42729A90eE7095e6fC145112f
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 55. Address: 0xE3714EB0B670724c088C13B3Ac3E0DddD1284b86
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 56. Address: 0xA11ACE199ADd4e06F136647e0a90D9f9aBF508A7
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 57. Address: 0x6Fc47a6846c036745fA4f5bF048DD0d54B5a14c2
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 58. Address: 0xb818388CcC895762A9e6320bCbcCbC92976a980D
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 59. Address: 0x98b1f617BcA0940765434EA49e908eAEB7bBee0E
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 60. Address: 0x2Ef8Ab1D5462FD4d92911f23722Bd0A8e632587b
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 61. Address: 0x024BB884Ec537fc7Ac51531deC7fEd147c785651
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 62. Address: 0x048778E2156b80E890EBeEC6172019D72c276387
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 63. Address: 0x11BFd4F699f5499F795d1c9D719A738340F47B0E
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 64. Address: 0xB73F0e10732D4fdab0d4005F6c62C6c6E1fC778e
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 65. Address: 0x9BB4B29618C52DC6D40407A81B9217d257f7cf32
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 66. Address: 0x5E915df8F75bf9B89F480244768C1BBaFcC4ce46
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 67. Address: 0x41E81Bfb7a16D1c5d56642cbaF3c604402D85b08
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 68. Address: 0x79ABE7701681578AFF8B2B3873CA383Bce9eb57B
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 69. Address: 0x0639D6bd0B9b2D4a6aca7C307021a8BFc6039813
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 70. Address: 0x783e5cFDE037fa9D3ED85134A8a6D680277401D0
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 71. Address: 0xb60B6eFB1223cC150c29729C8D219176c8bf627c
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 72. Address: 0x727c657AaED4601E4752569BB15A5dFdFA3c8aCB
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 73. Address: 0x9268D29386aC3A71478C68bc75E0Da36Ef6491ba
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 74. Address: 0xF145a46Fc3dC2be4C0c2d8Cc5A7322DC21346eed
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 75. Address: 0x080B0af419abdFD5266586fa02dd2d22986c5Dc7
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 76. Address: 0x332b68EC03f2D6b09cCFa6627aCBB3c7355B1A0A
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
# 77. Address: 0x027a643B4441252dBC369150C3dA41023Fca150f
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 78. Address: 0x6de11E13507d6242456A79d8F2EE2CE21B3812EF
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 79. Address: 0x5dc0a482b7524e9D5B7E837f5D663e6EA79c0C08
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 80. Address: 0x149DDCE6eBB34DdCB2EcCF63101Cf289EBC6b173
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 81. Address: 0x87F1DE2664A2e64303e9Cc1CCE36348B36f18331
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 82. Address: 0x38036af98cDE43C417D226827EFCfD74F4AEDA65
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=1
#    Stake Paid: 3000000000000000000 Wei
#
# 83. Address: 0x1d4FF3FABDCEcde6063a5e4d808078244517F17E
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 84. Address: 0xF1dd3e475de4707B7D4676B5bd49591738AfE132
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=1
#    Stake Paid: 2000000000000000000 Wei
#
# 85. Address: 0xdE836d62E2d0e10F9dA0de1EF0378493d4A25a81
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 86. Address: 0x819a269eec277715A39CF500D7d1502e2Cd7203f
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 87. Address: 0xD5bc924761Dd62f0dFE2951E7ED0623A8c4eC6B1
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 88. Address: 0xd9001E3B35429ebF4777aD6157f094F6B8F9cec2
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 89. Address: 0xD50804816860aBa1F13455e1408810909E61F2D5
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 90. Address: 0xBc3b0A7C84E95784C61ACc135b2468C6A22b8F5e
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 91. Address: 0x596a94a6602694ef2f2761921B64d43Dd6E61c68
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=1
#    Stake Paid: 2500000000000000000 Wei
#
# 92. Address: 0xa6D82F240d12eF8Ba072F04193f8A595BB677929
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 93. Address: 0x2A60649849502be21375DD299C5fb2e13CB2C0fD
#    Scenario: Normal Success
#    Synergy: DataCat=1, ResourceCat=0
#    Stake Paid: 1500000000000000000 Wei
#
# 94. Address: 0x92Bb7Ad7d065566E1de4CBc78189398A5D4dECCE
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 95. Address: 0xbF1165261ACa9218030Dd7Bd9cec06079Ee5cB8A
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 96. Address: 0xE02D9bE87C1e3BD53cf5B868ad95BDcf78352991
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=0
#    Stake Paid: 1000000000000000000 Wei
#
# 97. Address: 0x8A3F3Cb0022154D0fDBeC12f9f3874e9A6ca5118
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=2
#    Stake Paid: 4000000000000000000 Wei
#
# 98. Address: 0x96c44720a905DBa08B4D927f1CE5D7E81C9ea134
#    Scenario: Normal Success
#    Synergy: DataCat=2, ResourceCat=0
#    Stake Paid: 2000000000000000000 Wei
#
# 99. Address: 0x0e8c4cAC2962218F65D4FCA61c297f31F83B59E5
#    Scenario: Normal Success
#    Synergy: DataCat=0, ResourceCat=2
#    Stake Paid: 3000000000000000000 Wei
#
#
# Failed Attempts:

# %%
########################################################################
# 9) Check On-Chain Participant Data
########################################################################
p_count = contract_instance.functions.getParticipantCount().call()
print(f"\nFinal Participant Count on-chain: {p_count}")
print(f"Number of Successful Participants: {len(successful_users)}")
print(f"Number of Failed Attempts: {len(fail_reasons)}\n")

print("On-chain participant data (detailed):\n")
for idx in range(p_count):
    # Retrieve the participant address from the public array
    p_address = contract_instance.functions.participantList(idx).call()
    
    # Fetch their struct from the 'participants' mapping
    part_data = contract_instance.functions.participants(p_address).call()
    # part_data => (bool joined, uint8 dataCat, uint8 resourceCat, uint256 stakePaid, bool isRewarded)

    joined_status = part_data[0]
    data_cat = part_data[1]
    resource_cat = part_data[2]
    stake_paid = part_data[3]
    rewarded_status = part_data[4]

    # Convert numeric categories to more readable labels
    data_cat_label = ["Low", "Medium", "High"][data_cat] if data_cat in [0,1,2] else "InvalidCat"
    resource_cat_label = ["Low", "Medium", "High"][resource_cat] if resource_cat in [0,1,2] else "InvalidCat"

    # Convert stakePaid (Wei) to ETH
    stake_in_eth = w3.from_wei(stake_paid, "ether")

    # Print a summary for this participant
    print(f"Participant #{idx+1} @ {p_address}:")
    print(f"  joined={joined_status}, dataCat={data_cat_label}, resourceCat={resource_cat_label}")
    print(f"  stakePaid={stake_in_eth} ETH, isRewarded={rewarded_status}\n")
# Out:
# Final Participant Count on-chain: 99
# Number of Successful Participants: 99
# Number of Failed Attempts: 0
#
# On-chain participant data (detailed):
#
# Participant #1 @ 0x85bD17E7a0B9C96dc14470c69d9CeE6617F83aaB:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #2 @ 0x8E6670a1E36Ba00Bc2b21B6687C54447616A48Ef:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #3 @ 0x557598fd2fC58542f34C88746b1A479Ba3d1d753:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #4 @ 0x6653DBeDd9546a8B6c510778caC65b4474A21949:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #5 @ 0xB3c82BFAb7b450f1B13752071e6AaaB18b84556D:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #6 @ 0xC37D7889ad62de4Fc5798EC7A6fc8dfE6764BBDB:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #7 @ 0x92942835078BbFa9D68A7106aaE6d61a7EB557a2:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #8 @ 0x1cF8d0dA1062975273bBF853b8Aa3221CeF61608:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #9 @ 0xCA1368eFE9b8aE916368F1cA229283a712C0Cd26:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #10 @ 0x658b64D0B8faA91c81A353a11bdbB258cF3E4cAb:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #11 @ 0x7F728dFEA7FE0db60C7f664F5D96c077535e4dBf:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #12 @ 0x3bC80Dd91EF7dD35f8F6CDa6Ea5dEcd2eAF29679:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #13 @ 0xaE45f58c7c27020c341153A5caCFd6dA295d510D:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #14 @ 0x1af38d7bB2de936107ca004c24f5D62E3ac194FF:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #15 @ 0xd7C918590253605939367FC34c499932fDEEEF10:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #16 @ 0x213AAB4B4752921E933E1B118B27d4167b903292:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #17 @ 0x89022b2e9CbA63b7c6F1AeF5E8b83d1F92896f9F:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #18 @ 0xC4a76b530Ff27A469AA2fEd90f43057e8AE065B1:
#   joined=True, dataCat=Medium, resourceCat=High
#   stakePaid=3.5 ETH, isRewarded=False
#
# Participant #19 @ 0xD8EeD91e800c88D017722Fd575fED348E611C844:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #20 @ 0xBaeF5dB9044638E3A689dd6a03C0B2F3e0666cEa:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #21 @ 0xB49B0a1808c7a91934907836DAB637243cE4cF50:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #22 @ 0xd02Af983AE3d6DFB629d59d2C575b132fc8F9e5f:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #23 @ 0x3df3415de141d3488722D4142705A710dd9f2110:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #24 @ 0x8885218f6EAC369D7f212dFa5c734E95F6479777:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #25 @ 0x42E240fBC699d3317Ad5CAE37eBA891EFec04533:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #26 @ 0xE4aBD739c898534a5e505Ba3DEe13B47ACAC85F8:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #27 @ 0xD706C2C792c50d6caB33121385fCE904a6B0DF3A:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #28 @ 0x86B75C7Af0504E8B7c5B647D7BF7d2Fe714B9c34:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #29 @ 0xfd71BFeE615336700447069489A52Bc81Be63f0D:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #30 @ 0x687f1E5f43F4Eb53a40D03a79209DcdD3d31C560:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #31 @ 0xCe9b5AEA6CB4C72B436c5beF48271CE9cD20BEa5:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #32 @ 0xAaf813541E16FB099B97f6a7D42f4A387289431F:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #33 @ 0xd17b086EB6998a65053121507ee9a8eC4871ca51:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #34 @ 0x6072A2a56e1985090365211C36B364182Ca2095B:
#   joined=True, dataCat=Medium, resourceCat=High
#   stakePaid=3.5 ETH, isRewarded=False
#
# Participant #35 @ 0x63dd50a0f611752d44082EafEB46810B569425D4:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #36 @ 0x5A362d5b3fc39EB3262b7a36b68E07fb661Af049:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #37 @ 0xbBEA49B113cF2903d58274A6C5DcD35563b5b41F:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #38 @ 0x0C8174c241cDb42059FAF9Ad7e128605A3AAa15C:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #39 @ 0x971b53629599dcAE598f0A043649671E87a9C848:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #40 @ 0xe705925701E7967B51100f622a80EeaFf57F3962:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #41 @ 0xdeDb34f9Cfdf5491C802A9b65e2dAffaa6B731Ac:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #42 @ 0xEe78444f161B29b2f8133b672c4e77CB7E011B18:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #43 @ 0xb50d3dFc1AcFbBa21f8F1fbaa05d75Be163cEF64:
#   joined=True, dataCat=Medium, resourceCat=High
#   stakePaid=3.5 ETH, isRewarded=False
#
# Participant #44 @ 0xD220d8Cb830871744169c8b18B12eFE8b1BC3A8e:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #45 @ 0x98bb8D480bb5ca5fe7877355A407bea7f8D0cED1:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #46 @ 0x81A9F67d2FB3ACDB391AbdA8215dbDa7B91f8c2f:
#   joined=True, dataCat=Medium, resourceCat=High
#   stakePaid=3.5 ETH, isRewarded=False
#
# Participant #47 @ 0xa6f3dB8B631Cd8Dfd5a3E77854A363333c12cB01:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #48 @ 0xB4577599bFB26d3AE3178efD6012B91978ca65cC:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #49 @ 0x325aA4Acf101b5e16CD083C85707e3BDE1ff1B21:
#   joined=True, dataCat=Medium, resourceCat=High
#   stakePaid=3.5 ETH, isRewarded=False
#
# Participant #50 @ 0x7E426c8808c806A40F2656ef9aeE33Ec869319e9:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #51 @ 0xEfAcdE426DC0F6c51Ed44bF5C7858A0DC5A91791:
#   joined=True, dataCat=Medium, resourceCat=High
#   stakePaid=3.5 ETH, isRewarded=False
#
# Participant #52 @ 0x59dC9ec0582567d1233d90daCFF9A99318272390:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #53 @ 0xcAd363F36bBCF6135619716f7881d2D5D3eea8a7:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #54 @ 0xEDFA8d0c9BBaCEb42729A90eE7095e6fC145112f:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #55 @ 0xE3714EB0B670724c088C13B3Ac3E0DddD1284b86:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #56 @ 0xA11ACE199ADd4e06F136647e0a90D9f9aBF508A7:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #57 @ 0x6Fc47a6846c036745fA4f5bF048DD0d54B5a14c2:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #58 @ 0xb818388CcC895762A9e6320bCbcCbC92976a980D:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #59 @ 0x98b1f617BcA0940765434EA49e908eAEB7bBee0E:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #60 @ 0x2Ef8Ab1D5462FD4d92911f23722Bd0A8e632587b:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #61 @ 0x024BB884Ec537fc7Ac51531deC7fEd147c785651:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #62 @ 0x048778E2156b80E890EBeEC6172019D72c276387:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #63 @ 0x11BFd4F699f5499F795d1c9D719A738340F47B0E:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #64 @ 0xB73F0e10732D4fdab0d4005F6c62C6c6E1fC778e:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #65 @ 0x9BB4B29618C52DC6D40407A81B9217d257f7cf32:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #66 @ 0x5E915df8F75bf9B89F480244768C1BBaFcC4ce46:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #67 @ 0x41E81Bfb7a16D1c5d56642cbaF3c604402D85b08:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #68 @ 0x79ABE7701681578AFF8B2B3873CA383Bce9eb57B:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #69 @ 0x0639D6bd0B9b2D4a6aca7C307021a8BFc6039813:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #70 @ 0x783e5cFDE037fa9D3ED85134A8a6D680277401D0:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #71 @ 0xb60B6eFB1223cC150c29729C8D219176c8bf627c:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #72 @ 0x727c657AaED4601E4752569BB15A5dFdFA3c8aCB:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #73 @ 0x9268D29386aC3A71478C68bc75E0Da36Ef6491ba:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #74 @ 0xF145a46Fc3dC2be4C0c2d8Cc5A7322DC21346eed:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #75 @ 0x080B0af419abdFD5266586fa02dd2d22986c5Dc7:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #76 @ 0x332b68EC03f2D6b09cCFa6627aCBB3c7355B1A0A:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #77 @ 0x027a643B4441252dBC369150C3dA41023Fca150f:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #78 @ 0x6de11E13507d6242456A79d8F2EE2CE21B3812EF:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #79 @ 0x5dc0a482b7524e9D5B7E837f5D663e6EA79c0C08:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #80 @ 0x149DDCE6eBB34DdCB2EcCF63101Cf289EBC6b173:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #81 @ 0x87F1DE2664A2e64303e9Cc1CCE36348B36f18331:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #82 @ 0x38036af98cDE43C417D226827EFCfD74F4AEDA65:
#   joined=True, dataCat=High, resourceCat=Medium
#   stakePaid=3 ETH, isRewarded=False
#
# Participant #83 @ 0x1d4FF3FABDCEcde6063a5e4d808078244517F17E:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #84 @ 0xF1dd3e475de4707B7D4676B5bd49591738AfE132:
#   joined=True, dataCat=Low, resourceCat=Medium
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #85 @ 0xdE836d62E2d0e10F9dA0de1EF0378493d4A25a81:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #86 @ 0x819a269eec277715A39CF500D7d1502e2Cd7203f:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #87 @ 0xD5bc924761Dd62f0dFE2951E7ED0623A8c4eC6B1:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #88 @ 0xd9001E3B35429ebF4777aD6157f094F6B8F9cec2:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #89 @ 0xD50804816860aBa1F13455e1408810909E61F2D5:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #90 @ 0xBc3b0A7C84E95784C61ACc135b2468C6A22b8F5e:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #91 @ 0x596a94a6602694ef2f2761921B64d43Dd6E61c68:
#   joined=True, dataCat=Medium, resourceCat=Medium
#   stakePaid=2.5 ETH, isRewarded=False
#
# Participant #92 @ 0xa6D82F240d12eF8Ba072F04193f8A595BB677929:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #93 @ 0x2A60649849502be21375DD299C5fb2e13CB2C0fD:
#   joined=True, dataCat=Medium, resourceCat=Low
#   stakePaid=1.5 ETH, isRewarded=False
#
# Participant #94 @ 0x92Bb7Ad7d065566E1de4CBc78189398A5D4dECCE:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #95 @ 0xbF1165261ACa9218030Dd7Bd9cec06079Ee5cB8A:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #96 @ 0xE02D9bE87C1e3BD53cf5B868ad95BDcf78352991:
#   joined=True, dataCat=Low, resourceCat=Low
#   stakePaid=1 ETH, isRewarded=False
#
# Participant #97 @ 0x8A3F3Cb0022154D0fDBeC12f9f3874e9A6ca5118:
#   joined=True, dataCat=High, resourceCat=High
#   stakePaid=4 ETH, isRewarded=False
#
# Participant #98 @ 0x96c44720a905DBa08B4D927f1CE5D7E81C9ea134:
#   joined=True, dataCat=High, resourceCat=Low
#   stakePaid=2 ETH, isRewarded=False
#
# Participant #99 @ 0x0e8c4cAC2962218F65D4FCA61c297f31F83B59E5:
#   joined=True, dataCat=Low, resourceCat=High
#   stakePaid=3 ETH, isRewarded=False
