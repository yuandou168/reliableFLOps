# %%
import numpy as np
import logging
from tqdm import tqdm
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import pandas as pd
import os

# Configure logging
# logging.basicConfig(level=logging.DEBUG, format='%(levelname)s:%(message)s')
logger = logging.getLogger()

# ================== Utility Functions ==================
def softmax(x):
    """Compute softmax values for each set of scores in x."""
    e_x = np.exp(x - np.max(x))  # Stability improvement
    return e_x / e_x.sum()

def gini(x):
    """Robust Gini Coefficient Calculation"""
    x = np.sort(x)
    n = len(x)
    if n == 0 or np.sum(x) == 0:
        return 0.0
    cumx = np.cumsum(x, dtype=float)
    return (n + 1 - 2 * np.sum(cumx)/cumx[-1])/n

def sigmoid(x):
    """Sigmoid activation function."""
    return 1 / (1 + np.exp(-x))

def jain_fairness(x):
    """Improved Jain Index Calculation"""
    x = np.array(x)
    if np.sum(x) == 0:
        return 0.0
    return (np.sum(x)**2) / (len(x)*np.sum(x**2) + 1e-8) * sigmoid(np.mean(x)/10)

# ================== Node Class ==================
class Node:
    """Enhanced Federated Learning Node"""
    def __init__(self, node_id, init_stake=100, init_rep=100):
        self.id = node_id
        self.stake = init_stake
        self.reputation = init_rep
        self.total_reward = 0
        self.violations = 0
        self.participation = 0
        self.contrib_history = []
        self.cooldown = 0
        self.last_violation_round = -np.inf
        self.consecutive_committee = 0
        self.total_committee = 0
        self.identity_verified = True  # All nodes are verified

    def update_committee_status(self, is_in_committee):
        """Update committee status (including cooldown mechanism)"""
        if is_in_committee and self.cooldown <= 0:
            self.consecutive_committee += 1
            self.total_committee += 1
            self.cooldown = 3  # Example cooldown period
            logger.debug(f"Node {self.id} selected for committee. Cooldown set to {self.cooldown}.")
        else:
            if is_in_committee and self.cooldown > 0:
                logger.debug(f"Node {self.id} attempted to join committee but is in cooldown.")
            self.consecutive_committee = 0
        # Decrement cooldown if greater than 0
        if self.cooldown > 0:
            self.cooldown = max(0, self.cooldown - 1)
            logger.debug(f"Node {self.id} cooldown decremented to {self.cooldown}.")

    def act_normal(self):
        """Normal behavior pattern (with random fluctuation)"""
        base = np.random.normal(7, 1)
        fluctuation = np.random.choice([0.8, 1.0, 1.2], p=[0.2, 0.6, 0.2])
        contrib = max(0, base * fluctuation)
        self.contrib_history.append(contrib)
        logger.debug(f"Node {self.id} acted normally with contribution {contrib:.2f}.")
        return contrib

    def act_malicious(self, phase):
        """Enhanced robust malicious behavior method"""
        try:
            phase = int(phase)
            if phase == 1:  # High contribution attack
                contrib = max(9.5, np.random.normal(9.8, 0.3))
            elif phase == 2:    # Zero contribution attack
                contrib = 0
            elif phase == 3:    # Random attack (60% high contrib, 40% zero)
                contrib = np.random.choice([10, 0], p=[0.6, 0.4])
            else:
                raise ValueError(f"Invalid attack phase: {phase}")
        except Exception as e:
            logger.error(f"Node {self.id} attack phase error: {str(e)}")
            contrib = 0  # Safe default value

        self.contrib_history.append(contrib)
        logger.debug(f"Node {self.id} acted maliciously with contribution {contrib}.")
        return contrib

# ================== FLSystem Class ==================
class FLSystem:
    """Federated Learning System Simulator (Optimized for Stratified Sampling)"""
    def __init__(self, 
                 num_nodes=100,
                 base_reward=1000,
                 committee_size=10,
                 stake_weight=0.4,
                 rep_exponent=0.5,
                 init_stake=100,
                 init_rep=100,
                 malicious_ratio=0.1,
                 phase_switch_round=25,
                 sybil_resistance=False):  # Sybil resistance not needed
        # Save parameters as instance attributes
        self.sybil_resistance = sybil_resistance  # Not used in selection
        
        # Initialize nodes
        self.nodes = [Node(i+1, init_stake, init_rep) for i in range(num_nodes)]
        
        # Initialize malicious nodes
        self.malicious_nodes = self._init_malicious_nodes(malicious_ratio)
        
        # System parameters
        self.base_reward = base_reward
        self.malicious_ratio = malicious_ratio
        self.committee_size = committee_size
        self.stake_weight = stake_weight
        self.rep_exponent = rep_exponent
        self.phase_switch_round = phase_switch_round
        
        # Tracking state
        self.current_round = 0
        self.reputation_history = []
        self.reward_history = []
        self.gini_history = []
        self.fairness_history = []
        self.detection_history = []
        self.committee_history = []  # Committee history
        self.penalty_history = []  # Penalty history

    def _init_malicious_nodes(self, ratio):
        """Initialize malicious nodes (all nodes are verified)"""
        num_malicious = int(len(self.nodes) * ratio)
        malicious = self.nodes[:num_malicious]
        logger.info(f"Initialized {num_malicious} malicious nodes.")
        return malicious  # All malicious nodes are verified

    def _dynamic_malicious_threshold(self):
        """Dynamically calculate the threshold for malicious node detection"""
        # Get the latest contribution values of all nodes
        contribs = []
        for n in self.nodes:
            if n.contrib_history:
                contribs.append(n.contrib_history[-1])
            else:
                contribs.append(0)
        
        # Calculate the 30th percentile and adjust
        percentile_30 = np.percentile(contribs, 30)
        threshold = percentile_30 * 0.7 + 1e-8  # Add a tiny value to prevent division by zero
        logger.debug(f"Dynamic malicious threshold calculated: {threshold:.4f}")
        return threshold

    def select_committee(self, num_strata=3):
        """
        Select committee members using stratified sampling based on reputation and cooldown.

        Parameters:
            num_strata (int): Number of strata to divide the nodes into.

        Returns:
            selected (list): List of selected committee nodes.
        """
        # Sort nodes by reputation descending
        sorted_nodes = sorted(self.nodes, key=lambda x: x.reputation, reverse=True)
        strata_size = len(sorted_nodes) // num_strata
        strata = [sorted_nodes[i*strata_size : (i+1)*strata_size] for i in range(num_strata)]
        
        # Handle any remaining nodes by adding to the last stratum
        if len(sorted_nodes) % num_strata != 0:
            strata[-1].extend(sorted_nodes[num_strata*strata_size:])
            logger.debug(f"Added {len(sorted_nodes) % num_strata} nodes to the last stratum.")

        selected = []
        quotas = [self.committee_size // num_strata] * num_strata  # Initial quota per stratum
        remaining_quota = self.committee_size - sum(quotas)

        # Distribute remaining_quota among the first few strata
        for i in range(remaining_quota):
            quotas[i % num_strata] += 1
        logger.debug(f"Final Quotas per Stratum: {quotas}")

        # First Pass: Select based on strata quotas
        for idx, (stratum, quota) in enumerate(zip(strata, quotas)):
            # Filter eligible candidates (not in cooldown)
            candidates = [node for node in stratum if node.cooldown <= 0]
            eligible_count = len(candidates)
            logger.debug(f"Stratum {idx+1}: {eligible_count} eligible candidates.")

            if eligible_count == 0:
                logger.debug(f"Stratum {idx+1} has no eligible candidates. Quota remains unfilled.")
                continue  # Quota will be redistributed later

            # Determine how many to select from this stratum
            select_count = min(quota, eligible_count)
            select_count = max(1, select_count)  # Ensure at least one selection if possible

            # Calculate selection probabilities based on reputation
            if eligible_count == 1:
                probabilities = [1.0]
            else:
                reputation_scores = np.array([node.reputation for node in candidates], dtype=float)
                probabilities = softmax(reputation_scores ** self.rep_exponent)
            
            # Select nodes
            selected_nodes = np.random.choice(candidates, size=select_count, p=probabilities, replace=False)
            selected.extend(selected_nodes)
            logger.debug(f"Stratum {idx+1}: Selected {select_count} nodes.")

        # Check if committee size is met
        if len(selected) < self.committee_size:
            logger.debug(f"Committee size after first pass: {len(selected)}. Redistributing remaining quota.")
            remaining_quota = self.committee_size - len(selected)
            
            # Gather all eligible nodes not yet selected
            eligible_nodes = [node for node in self.nodes if node.cooldown <= 0 and node not in selected]
            eligible_count = len(eligible_nodes)
            logger.debug(f"Total eligible nodes for redistribution: {eligible_count}.")

            if eligible_count >= remaining_quota:
                if eligible_count == 1:
                    probabilities = [1.0]
                else:
                    reputation_scores = np.array([node.reputation for node in eligible_nodes], dtype=float)
                    probabilities = softmax(reputation_scores ** self.rep_exponent)
                
                # Select remaining_quota nodes
                selected_nodes = np.random.choice(eligible_nodes, size=remaining_quota, p=probabilities, replace=False)
                selected.extend(selected_nodes)
                logger.debug(f"Redistributed and selected {remaining_quota} additional nodes.")
            elif eligible_count > 0:
                # Select all remaining eligible nodes
                selected.extend(eligible_nodes)
                logger.warning(f"Only {eligible_count} eligible nodes available for redistribution. Committee size reduced.")
        
        # Final Check
        if len(selected) < self.committee_size:
            logger.warning(f"Unable to fill the committee to the desired size of {self.committee_size}. "
                           f"Only {len(selected)} members selected.")
        else:
            logger.debug(f"Successfully selected {len(selected)} committee members.")
        
        # Update node statuses
        for node in self.nodes:
            node.update_committee_status(node in selected)
        
        self.committee_history.append([node.id for node in selected])
        logger.info(f"Round {self.current_round + 1}: Committee selected with {len(selected)} members.")
        
        return selected

    def calculate_reward(self, node, avg_rep):
        """Dynamic hybrid reward calculation"""
        # Effective stake (anti-monopoly)
        avg_stake = np.mean([n.stake for n in self.nodes])
        effective_stake = min(node.stake, avg_stake * 3)
        
        # Time-decayed contribution
        hist_contrib = sum(c * (0.9**t) for t, c in enumerate(reversed(node.contrib_history[-5:])))
        
        # Dynamic weights using sigmoid function
        alpha = sigmoid((avg_rep - 100)/50) * self.stake_weight
        beta = 1 - alpha
        
        # Diversity bonus
        # diversity_bonus = 1 - gini([n.reputation for n in self.nodes])
        diversity_bonus = jain_fairness([n.reputation for n in self.nodes])

        # Committee reward
        committee_reward = 40 * diversity_bonus if node in self.committee_history[-1] else 0
        
        # Total reward calculation
        total = (alpha * self.base_reward * (effective_stake / (sum(n.stake for n in self.nodes) + 1e-8)) +
                beta * self.base_reward * (hist_contrib / (sum(n.contrib_history[-1] for n in self.nodes) + 1e-8)) +
                committee_reward) * diversity_bonus
        
        return max(total, 0)

    def update_reputation(self, node, contribution):
        """Robust reputation update system"""
        # Dynamic decay
        age_factor = 1 - 1/(1 + node.participation/100)
        delta = 0.88 + 0.07 * age_factor
        
        # Contribution quality
        contrib_quality = sigmoid((contribution - 5)/3)
        
        # Stability evaluation
        if len(node.contrib_history) >= 5:
            stability = 1 - np.std(node.contrib_history[-5:])/5
        else:
            stability = 0.8
            
        new_rep = (node.reputation * delta +
                  contrib_quality * 50 +
                  stability * 30)
        
        # Dynamic cap
        rep_cap = 500 if self.current_round > 50 else 300
        return np.clip(new_rep, 0, rep_cap)

    def detect_malicious(self, node):
        """Hybrid detection strategy"""
        # Basic detection
        if len(node.contrib_history) < 5:
            return False
        
        window = node.contrib_history[-5:]
        avg = np.mean(window)
        std = np.std(window)
        threshold = self._dynamic_malicious_threshold()
        
        # Rule 1: Persistent low contributions
        condition1 = avg < threshold * 0.7
        
        # Rule 2: Abnormal fluctuation
        condition2 = std < threshold * 0.4
        
        # Rule 3: Sudden behavior change
        prev_avg = np.mean(node.contrib_history[-10:-5]) if len(node.contrib_history) >= 10 else 7
        condition3 = abs(avg - prev_avg) > 5
        
        is_malicious = (condition1 and condition2) or condition3
        logger.debug(f"Node {node.id} detection: Condition1={condition1}, Condition2={condition2}, Condition3={condition3} -> {is_malicious}")
        return is_malicious

    def run_round(self):
        """Execute simulation round"""        
        # Improved phase calculation logic
        base_phase = 1 if self.current_round < self.phase_switch_round else 2
        phase_variation = int(self.current_round/30) % 2
        attack_phase = min(base_phase + phase_variation, 3)
        logger.info(f"Round {self.current_round + 1}: Phase {attack_phase}")
        
        contributions = []  # Initialize contributions list
        
        # Collect all nodes' contributions
        for node in self.nodes:
            if node in self.malicious_nodes:
                contrib = node.act_malicious(attack_phase)
            else:
                contrib = node.act_normal()
            contributions.append(contrib)  # Add this line

        # Committee selection
        self.committee = self.select_committee()
        
        # System updates
        avg_rep = np.mean([n.reputation for n in self.nodes])
        rewards = []
        detected = 0
        penalties = []
        
        for node, contrib in zip(self.nodes, contributions):
            # Detection and penalty
            if self.detect_malicious(node):
                penalty = min(0.3 * node.reputation + 0.1 * node.stake, node.reputation*0.5)
                penalties.append(penalty)
                node.reputation -= penalty
                node.violations += 1
                detected += 1
                logger.debug(f"Node {node.id} detected as malicious. Penalty applied: {penalty:.2f}")
            else:
                node.reputation = self.update_reputation(node, contrib)
                logger.debug(f"Node {node.id} reputation updated to {node.reputation:.2f}")
            
            # Reward calculation
            reward = self.calculate_reward(node, avg_rep)
            node.total_reward += reward
            rewards.append(reward)
            logger.debug(f"Node {node.id} received reward: {reward:.2f}")
            
            node.participation += 1

        # Record metrics
        self.penalty_history.append(penalties)
        self.reputation_history.append([n.reputation for n in self.nodes])
        self.reward_history.append(rewards)
        self.gini_history.append(gini(rewards))
        self.fairness_history.append(jain_fairness(rewards))
        self.detection_history.append(detected)
        self.current_round += 1
        logger.info(f"Round {self.current_round}: Detected {detected} malicious nodes.")

# ================== Visualization Module ==================
def plot_metrics(system, label="System"):
    """System-Wide Metrics Visualization"""
    
    plt.figure(figsize=(18, 12))

    # ---------- Fairness metrics -------------
    plt.subplot(2, 2, 1)
    rewards = np.array(system.reward_history)
    rounds = np.arange(rewards.shape[0])
    num_nodes = rewards.shape[1]

    plt.plot(system.gini_history, linewidth=3, label='Gini Coefficient')
    plt.plot(system.fairness_history, linewidth=3, label="Jain's Fairness Index")
    plt.axhline(0.3, color='green', linestyle='--', label='Healthy Gini Threshold')
    plt.axhline(1, color='red', linestyle='--', label='Ideal Fairness Threshold')
    plt.title(f'{label} - Fairness Metrics Dynamics\nTotal Nodes: {num_nodes} | Rounds: {len(rounds)}', 
             fontsize=14, pad=20)
    plt.xlabel('Round', fontsize=12)
    plt.ylabel('Ratio', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)

    plt.legend()
    plt.tight_layout()
    
    # --------- Reputation Distribution -----------
    plt.subplot(2, 2, 2)
    if not system.reputation_history:
        print("警告：无声誉数据可供可视化")
        plt.title('声誉数据未找到')
        return
    
    reps = np.array(system.reputation_history)
    rounds = np.arange(reps.shape[0])
    num_nodes = reps.shape[1]
    
    # Identify malicious nodes
    malicious_ids = [n.id-1 for n in system.malicious_nodes] if system.malicious_nodes else []
    honest_ids = [i for i in range(num_nodes) if i not in malicious_ids]
    
    # Plot individual traces with group coloring
    for node_id in range(num_nodes):
        color = 'tomato' if node_id in malicious_ids else 'skyblue'
        alpha = 0.2 if node_id in malicious_ids else 0.1
        plt.plot(rounds, reps[:, node_id], 
                color=color, 
                alpha=alpha, 
                linewidth=0.8,
                zorder=1)
    
    # Calculate group averages
    if malicious_ids:
        malicious_avg = np.mean(reps[:, malicious_ids], axis=1)
        malicious_q1 = np.percentile(reps[:, malicious_ids], 25, axis=1)
        malicious_q3 = np.percentile(reps[:, malicious_ids], 95, axis=1)
    else:
        malicious_avg = np.array([])
        malicious_q1 = np.array([])
        malicious_q3 = np.array([])
    
    honest_avg = np.mean(reps[:, honest_ids], axis=1)
    honest_q1 = np.percentile(reps[:, honest_ids], 25, axis=1)
    honest_q3 = np.percentile(reps[:, honest_ids], 95, axis=1)
    
    # Plot group averages
    plt.plot(rounds, honest_avg, 
            color='dodgerblue', 
            linewidth=3, 
            linestyle='-',
            label=f'Honest Nodes Avg (μ={honest_avg[-1]:.1f})',
            zorder=4)
    
    if len(malicious_avg) > 0:
        plt.plot(rounds, malicious_avg, 
                color='crimson', 
                linewidth=3, 
                linestyle='--',
                label=f'Malicious Nodes Avg (μ={malicious_avg[-1]:.1f})',
                zorder=5)

    # Plot overall mean comparison
    # total_avg = np.mean(reps, axis=1)
    # plt.plot(rounds, np.mean(reps, axis=1),
    #         color='gold', 
    #         linewidth=3,
    #         linestyle=':',
    #         label='Overall Mean',
    #         zorder=3)
    
    # Plot honest nodes statistics
    plt.fill_between(rounds, honest_q1, honest_q3,
                    color='skyblue', alpha=0.3,
                    label='Honest IQR', zorder=2)
    plt.plot(rounds, honest_avg,
            color='dodgerblue', lw=3,
            label=f'[{len(honest_ids)}] Honest Avg (Final: {honest_avg[-1]:.1f})')
    
    # Plot malicious nodes statistics (if any)
    if len(malicious_avg) > 0:
        plt.fill_between(rounds, malicious_q1, malicious_q3,
                        color='lightcoral', alpha=0.3,
                        label='Malicious IQR', zorder=2)
        plt.plot(rounds, malicious_avg,
                color='crimson', lw=3, linestyle='--',
                label=f'[{len(malicious_ids)}] Malicious Avg (Final: {malicious_avg[-1]:.1f})')
    
    # Formatting
    plt.title(f'{label} - Reputation Distribution Dynamics\n'
             f'Total Nodes: {num_nodes} (Malicious: {len(malicious_ids)}) | Rounds: {len(rounds)}', 
             fontsize=14, pad=20)
    plt.xlabel('Round', fontsize=12)
    plt.ylabel('Reputation Value', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    
    # Create layered legend
    legend_elements = [
        Patch(facecolor='skyblue', alpha=0.3, label='Honest IQR'),
        Line2D([0], [0], color='dodgerblue', lw=2, label=f'[{len(honest_ids)}] Honest Average'),
    ]
    
    if len(malicious_avg) > 0:
        legend_elements.extend([
            Patch(facecolor='lightcoral', alpha=0.3, label='Malicious IQR'),
            Line2D([0], [0], color='crimson', lw=2, ls='--', label=f'[{len(malicious_ids)}] Malicious Average'),
        ])
    
    legend_elements.extend([
        # Line2D([0], [0], color='gold', lw=2, ls=':', label='Overall Mean'),
        Line2D([0], [0], color='skyblue', alpha=0.3, lw=1, label='Honest Traces'),
    ])
    
    if len(malicious_avg) > 0:
        legend_elements.append(Line2D([0], [0], color='tomato', alpha=0.3, lw=1, label='Malicious Traces'))
    
    plt.legend(handles=legend_elements, 
              loc='upper center',
              bbox_to_anchor=(0.2, 0.35),  
              ncol=1,
              frameon=False,
              fontsize=10)
    
    # Add dynamic statistical annotations
    stats_text = []
    if len(malicious_avg) > 0:
        stats_text.append(f"Malicious Reputation Δ: {malicious_avg[-1]-malicious_avg[0]:.1f}")
    stats_text.extend([
        f"Honest Reputation Δ: {honest_avg[-1]-honest_avg[0]:.1f}",
        f"Final Reputation Range: {np.min(reps[-1]):.1f}-{np.max(reps[-1]):.1f}",
        # f"Honest/Honest Ratio: {honest_avg[-1]/(total_avg[-1]+1e-8):.1f}x"
    ])
    
    plt.annotate('\n'.join(stats_text), 
                xy=(0.95, 0.6),
                xycoords='axes fraction',
                ha='right',
                va='bottom',
                fontsize=10,
                bbox=dict(boxstyle='round', alpha=0.9, facecolor='white'))

    
    # -------- Security Detection ------------
    plt.subplot(2, 2, 3)
    if malicious_ids:
        plt.bar(range(len(system.detection_history)), system.detection_history, alpha=0.6)
        plt.title(f'{label} - Malicious Node Detection\n'
                  f'Nodes: {num_nodes} (Malicious: {len(malicious_ids)}) | Rounds: {len(rounds)}',
                  fontsize=14, pad=20)
        plt.xlabel('Round', fontsize=12)
        plt.ylabel('Total Detected', fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
    
    # -------- Reward Distribution ------------
    plt.subplot(2, 2, 4)
    """Dynamic reward distribution visualization (including malicious/honest node distinction)"""
    if not system.reward_history:
        print("警告：无奖励数据可供可视化")
        return
    # Data preparation
    rewards = np.array(system.reward_history)
    rounds = np.arange(rewards.shape[0])
    num_nodes = rewards.shape[1]
    
    # Identify malicious nodes
    malicious_ids = [n.id-1 for n in system.malicious_nodes] if system.malicious_nodes else []
    honest_ids = [i for i in range(num_nodes) if i not in malicious_ids]
    
    # Plot individual reward traces with group coloring
    for node_id in range(num_nodes):
        color = 'tomato' if node_id in malicious_ids else 'skyblue'
        alpha = 0.15 if node_id in malicious_ids else 0.08
        plt.plot(rounds, rewards[:, node_id], 
                color=color, 
                alpha=alpha, 
                linewidth=0.6,
                zorder=1)
    
    # Calculate group statistics
    if malicious_ids:
        malicious_avg = np.mean(rewards[:, malicious_ids], axis=1)
        malicious_q1 = np.percentile(rewards[:, malicious_ids], 25, axis=1)
        malicious_q3 = np.percentile(rewards[:, malicious_ids], 95, axis=1)
    else:
        malicious_avg = np.array([])
        malicious_q1 = np.array([])
        malicious_q3 = np.array([])
    
    honest_avg = np.mean(rewards[:, honest_ids], axis=1)
    honest_q1 = np.percentile(rewards[:, honest_ids], 25, axis=1)
    honest_q3 = np.percentile(rewards[:, honest_ids], 95, axis=1)
    
    # Plot group averages
    plt.plot(rounds, honest_avg, 
            color='dodgerblue', 
            linewidth=3, 
            linestyle='-',
            label=f'Honest Nodes Avg (μ={honest_avg[-1]:.1f})',
            zorder=4)
    
    if len(malicious_avg) > 0:
        plt.plot(rounds, malicious_avg, 
                color='crimson', 
                linewidth=3, 
                linestyle='--',
                label=f'Malicious Nodes Avg (μ={malicious_avg[-1]:.1f})',
                zorder=5)

    # Plot overall mean comparison
    # total_avg = np.mean(reps, axis=1)
    # plt.plot(rounds, np.mean(reps, axis=1),
    #         color='gold', 
    #         linewidth=3,
    #         linestyle=':',
    #         label='Overall Mean',
    #         zorder=3)
    
    # Plot honest nodes statistics
    plt.fill_between(rounds, honest_q1, honest_q3,
                    color='skyblue', alpha=0.3,
                    label='Honest IQR')
    plt.plot(rounds, honest_avg,
            color='dodgerblue', lw=3,
            label=f'[{len(honest_ids)}] Honest Avg (Final: {honest_avg[-1]:.1f})')
    
    # Plot malicious nodes statistics (if any)
    if len(malicious_avg) > 0:
        plt.fill_between(rounds, malicious_q1, malicious_q3,
                        color='lightcoral', alpha=0.3,
                        label='Malicious IQR')
        plt.plot(rounds, malicious_avg,
                color='crimson', lw=3, linestyle='--',
                label=f'[{len(malicious_ids)}] Malicious Avg (Final: {malicious_avg[-1]:.1f})')
    
    # Overall statistics reference lines
    plt.title(f'{label} - Reward Distribution Dynamics\n'
             f'Nodes: {num_nodes} (Malicious: {len(malicious_ids)}) | Rounds: {len(rounds)}',
             fontsize=14, pad=20)
    plt.xlabel('Training Rounds', fontsize=12)
    plt.ylabel('Reward Value', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    
    # Create layered legend
    legend_elements = [
        Patch(facecolor='skyblue', alpha=0.3, label='Honest IQR'),
        Line2D([0], [0], color='dodgerblue', lw=2, label=f'[{len(honest_ids)}] Honest Average'),
    ]
    
    if len(malicious_avg) > 0:
        legend_elements.extend([
            Patch(facecolor='lightcoral', alpha=0.3, label='Malicious IQR'),
            Line2D([0], [0], color='crimson', lw=2, ls='--', label=f'[{len(malicious_ids)}] Malicious Average'),
        ])
    
    legend_elements.extend([
        # Line2D([0], [0], color='gold', lw=2, ls=':', label='Overall Mean'),
        Line2D([0], [0], color='skyblue', alpha=0.3, lw=1, label='Honest Traces'),
    ])
    
    if len(malicious_avg) > 0:
        legend_elements.append(Line2D([0], [0], color='tomato', alpha=0.3, lw=1, label='Malicious Traces'))
    
    plt.legend(handles=legend_elements,
              loc='upper center',
              bbox_to_anchor=(0.2, 0.35),
              ncol=1,
              frameon=False,
              fontsize=10)
    
    # Add dynamic statistical annotations
    stats_text = []
    if len(malicious_avg) > 0:
        stats_text.append(f"Malicious Reward Δ: {malicious_avg[-1]-malicious_avg[0]:.1f}")
    stats_text.extend([
        f"Honest Reward Δ: {honest_avg[-1]-honest_avg[0]:.1f}",
        f"Final Reward Range: {np.min(rewards[-1]):.1f}-{np.max(rewards[-1]):.1f}",
        # f"Honest/Honest Ratio: {honest_avg[-1]/(total_avg[-1]+1e-8):.1f}x"
    ])
    
    plt.annotate('\n'.join(stats_text), 
                xy=(0.95, 0.8),
                xycoords='axes fraction',
                ha='right',
                va='bottom',
                fontsize=10,
                bbox=dict(boxstyle='round', alpha=0.9, facecolor='white'))
    
    plt.tight_layout()
    plt.show()

# =================== Simulation Report =====================
def generate_simulation_report(system, filename):
    """
    Generates simulation reports for an FLSystem instance and saves them as CSV files.

    Parameters:
        system (FLSystem): The federated learning system instance containing simulation data.
        filename (str): The base filename for the generated reports. The function will create
                        two CSV files with suffixes '_round_metrics.csv' and '_node_summary.csv'.

    Returns:
        tuple: A tuple containing two pandas DataFrames:
               (round_metrics_df, node_summary_df)
    """
    # Validate the filename extension
    if not filename.lower().endswith('.csv'):
        raise ValueError("Filename must end with '.csv'")
    
    # Derive base name without extension
    base, ext = os.path.splitext(filename)
    
    # Define filenames for round metrics and node summary
    round_metrics_filename = f"{base}_round_metrics.csv"
    node_summary_filename = f"{base}_node_summary.csv"
    
    # ------------------ Extract Per-Round Metrics ------------------
    rounds = list(range(1, system.current_round + 1))
    gini = system.gini_history
    fairness = system.fairness_history
    detected = system.detection_history
    penalties = system.penalty_history  # List of lists
    committee_history = system.committee_history  # List of lists
    
    # Calculate total penalties per round
    total_penalties = [sum(penalty_round) for penalty_round in penalties]
    
    # Format committee members as comma-separated strings
    committee_members = [', '.join(map(str, committee)) for committee in committee_history]
    
    # Create a DataFrame for per-round metrics
    round_metrics_df = pd.DataFrame({
        'Round': rounds,
        'Gini Coefficient': gini,
        'Fairness Index': fairness,
        'Detected Malicious Nodes': detected,
        'Total Penalties': total_penalties,
        'Committee Members': committee_members
    })
    
    # ------------------ Extract Per-Node Summary Metrics ------------------
    node_ids = [node.id for node in system.nodes]
    stakes = [node.stake for node in system.nodes]
    final_reputations = [node.reputation for node in system.nodes]
    total_rewards = [node.total_reward for node in system.nodes]
    violations = [node.violations for node in system.nodes]
    participation = [node.participation for node in system.nodes]
    total_committee = [node.total_committee for node in system.nodes]
    cooldowns = [node.cooldown for node in system.nodes]
    
    # Create a DataFrame for per-node summary
    node_summary_df = pd.DataFrame({
        'Node ID': node_ids,
        'Stake': stakes,
        'Final Reputation': final_reputations,
        'Total Reward': total_rewards,
        'Violations': violations,
        'Participation Count': participation,
        'Total Committee Memberships': total_committee,
        'Current Cooldown': cooldowns
    })
    
    # ------------------ Save DataFrames to CSV Files ------------------
    try:
        # Save round metrics
        round_metrics_df.to_csv(round_metrics_filename, index=False)
        print(f"Round metrics saved to {round_metrics_filename}")
        
        # Save node summary
        node_summary_df.to_csv(node_summary_filename, index=False)
        print(f"Node summary metrics saved to {node_summary_filename}")
        
    except Exception as e:
        print(f"Error saving simulation reports: {e}")
        raise e
    
    # ------------------ Return DataFrames ------------------
    return round_metrics_df, node_summary_df

# %%
# ================== Main Program ==================
# if __name__ == "__main__":
#     # Set fixed random seed for reproducibility
#     np.random.seed(1411758002)
#     import random
#     random.seed(1411758002)
    
#     # committee_size 

#     # Initialize FL Systems
#     system_with_malicious_0p1 = FLSystem(
#         num_nodes=100,
#         base_reward=1000,
#         committee_size=5,  # Desired committee size
#         stake_weight=0.4,
#         rep_exponent=0.5,
#         malicious_ratio=0.1,  # 10% malicious nodes
#         phase_switch_round=30,
#         sybil_resistance=False  # Sybil resistance not considered
#     )
    
#     system_with_malicious_0p15 = FLSystem(
#         num_nodes=100,
#         base_reward=1000,
#         committee_size=5,  # Desired committee size
#         stake_weight=0.4,
#         rep_exponent=0.5,
#         malicious_ratio=0.15,  # 15% malicious nodes
#         phase_switch_round=30,
#         sybil_resistance=False  # Sybil resistance not considered
#     )

#     system_with_malicious_0p2 = FLSystem(
#         num_nodes=100,
#         base_reward=1000,
#         committee_size=5,  # Desired committee size
#         stake_weight=0.4,
#         rep_exponent=0.5,
#         malicious_ratio=0.2,  # 10% malicious nodes
#         phase_switch_round=30,
#         sybil_resistance=False  # Sybil resistance not considered
#     )

#     system_with_malicious_0p25 = FLSystem(
#         num_nodes=100,
#         base_reward=1000,
#         committee_size=5,  # Desired committee size
#         stake_weight=0.4,
#         rep_exponent=0.5,
#         malicious_ratio=0.25,  # 25% malicious nodes
#         phase_switch_round=30,
#         sybil_resistance=False  # Sybil resistance not considered
#     )
    
#     system_with_malicious_0p3 = FLSystem(
#         num_nodes=100,
#         base_reward=1000,
#         committee_size=5,  # Desired committee size
#         stake_weight=0.4,
#         rep_exponent=0.5,
#         malicious_ratio=0.3,  # 30% malicious nodes
#         phase_switch_round=30,
#         sybil_resistance=False  # Sybil resistance not considered
#     )

#     system_without_malicious = FLSystem(
#         num_nodes=100,
#         base_reward=1000,
#         committee_size=5,
#         stake_weight=0.4,
#         rep_exponent=0.5,
#         malicious_ratio=0.0,  # No malicious nodes
#         phase_switch_round=30,
#         sybil_resistance=False
#     )
    
#     # Run Simulations
#     print("开始运行包含恶意节点的模拟...")
#     for _ in tqdm(range(80), desc="包含恶意节点"):
#         system_with_malicious_0p1.run_round()
#         system_with_malicious_0p15.run_round()
#         system_with_malicious_0p2.run_round()
#         system_with_malicious_0p25.run_round()
#         system_with_malicious_0p3.run_round()
    
#     print("\n开始运行不包含恶意节点的模拟...")
#     for _ in tqdm(range(80), desc="不包含恶意节点"):
#         system_without_malicious.run_round()
    
#     # Generate Reports
#     print("\n生成模拟报告...")
#     # Assuming generate_simulation_report is defined elsewhere
#     report_with_malicious = generate_simulation_report(system_with_malicious_0p1, filename="simulation_report_with_malicious_0p1.csv")
#     report_without_malicious = generate_simulation_report(system_without_malicious, filename="simulation_report_without_malicious.csv")
#     report_with_malicious = generate_simulation_report(system_with_malicious_0p15, filename="simulation_report_with_malicious_0p15.csv")
#     report_without_malicious = generate_simulation_report(system_with_malicious_0p2, filename="simulation_report_without_malicious_0p2.csv")
#     report_with_malicious = generate_simulation_report(system_with_malicious_0p25, filename="simulation_report_with_malicious_0p25.csv")
#     report_without_malicious = generate_simulation_report(system_with_malicious_0p3, filename="simulation_report_without_malicious_0p3.csv")
    
#     # Verify Committee Sizes
#     def verify_committee_size(system, expected_size=5):
#         """
#         Verify that each committee in the history meets the expected size.
#         """
#         for round_num, committee in enumerate(system.committee_history, 1):
#             if len(committee) != expected_size:
#                 print(f"Round {round_num}: Committee size {len(committee)} does not match expected {expected_size}.")
#         print("Verification complete.")

#     print("\n验证包含恶意节点的系统委员会规模...")
#     verify_committee_size(system_with_malicious_0p1, expected_size=5)
#     verify_committee_size(system_with_malicious_0p15, expected_size=5)
#     verify_committee_size(system_with_malicious_0p2, expected_size=5)
#     verify_committee_size(system_with_malicious_0p25, expected_size=5)
#     verify_committee_size(system_with_malicious_0p3, expected_size=5)
    
    
#     print("\n验证不包含恶意节点的系统委员会规模...")
#     verify_committee_size(system_without_malicious, expected_size=5)
    
#     # Generate Visualization
#     print("\n生成包含恶意节点的系统的可视化分析图表...")
#     plot_metrics(system_with_malicious_0p1, label="With Malicious Nodes")

#     plot_metrics(system_with_malicious_0p15, label="With Malicious Nodes")
#     plot_metrics(system_with_malicious_0p2, label="With Malicious Nodes")
#     plot_metrics(system_with_malicious_0p25, label="With Malicious Nodes")
#     plot_metrics(system_with_malicious_0p3, label="With Malicious Nodes")
    
#     print("\n生成不包含恶意节点的系统的可视化分析图表...")
#     plot_metrics(system_without_malicious, label="Without Malicious Nodes")
    
N =1000
CS = 5
Base = 1000
rep_exponent = 0.5
stake_weight = 0.4
R = 80
# ================== Main Program ==================
if __name__ == "__main__":
    # Set fixed random seed for reproducibility
    np.random.seed(1411758002)
    import random
    random.seed(1411758002)
    

    
    # Initialize FL Systems with different malicious ratios
    systems = {
        "with_malicious_0p10": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent= rep_exponent,
            malicious_ratio=0.1,  # 10% malicious nodes
            phase_switch_round=30,
            # Sybil resistance not considered
        ),
        "with_malicious_0p15": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.15,  # 15% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "with_malicious_0p20": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.2,  # 20% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "with_malicious_0p25": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.25,  # 25% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "with_malicious_0p30": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.3,  # 30% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "without_malicious": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.0,  # No malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False
        )
    }
    
    # Define the number of rounds for simulations
    rounds_with_malicious = R
    rounds_without_malicious = R

    # Run Simulations for systems with malicious nodes
    print("开始运行包含恶意节点的模拟...")
    for _ in tqdm(range(rounds_with_malicious), desc="包含恶意节点"):
        for key in ["with_malicious_0p10", "with_malicious_0p15", "with_malicious_0p20", "with_malicious_0p25", "with_malicious_0p30"]:
            systems[key].run_round()
    
    # Run Simulations for system without malicious nodes
    print("\n开始运行不包含恶意节点的模拟...")
    for _ in tqdm(range(rounds_without_malicious), desc="不包含恶意节点"):
        systems["without_malicious"].run_round()
    
    # Generate Reports
    print("\n生成模拟报告...")
    for key in systems:
        filename = f"simulation_report_{key}.csv"
        generate_simulation_report(systems[key], filename=filename)
    
    # Verify Committee Sizes
    def verify_committee_size(system, expected_size=CS):
        """
        Verify that each committee in the history meets the expected size.
        """
        for round_num, committee in enumerate(system.committee_history, 1):
            if len(committee) != expected_size:
                print(f"Round {round_num}: Committee size {len(committee)} does not match expected {expected_size}.")
        print("Verification complete.")
    
    # Verify committee sizes for all systems
    print("\n验证所有系统的委员会规模...")
    for key in systems:
        print(f"\n验证系统 '{key}' 的委员会规模...")
        verify_committee_size(systems[key], expected_size=CS)
    
    # Generate Visualization for each system
    print("\n生成系统的可视化分析图表...")
    for key in systems:
        print(key)
        label = "With Malicious Nodes" if "with_malicious" in key else "Without Malicious Nodes"
        print(f"生成系统 '{key}' 的图表...")
        plot_metrics(systems[key], label=key)
    
    print("\n所有模拟和报告生成完毕。")
# Out:
# INFO:Initialized 100 malicious nodes.
# INFO:Initialized 150 malicious nodes.
# INFO:Initialized 200 malicious nodes.
# INFO:Initialized 250 malicious nodes.
# INFO:Initialized 300 malicious nodes.
# INFO:Initialized 0 malicious nodes.
# 开始运行包含恶意节点的模拟...
# 包含恶意节点:   0%|          | 0/80 [00:00<?, ?it/s]INFO:Round 1: Phase 1
# DEBUG:Node 1 acted maliciously with contribution 9.772893432211298.
# INFO:Round 1: Phase 1
# DEBUG:Node 1 acted maliciously with contribution 9.772893432211298.
# DEBUG:Node 2 acted maliciously with contribution 9.671339354494883.
# DEBUG:Node 3 acted maliciously with contribution 9.5.
# DEBUG:Node 4 acted maliciously with contribution 9.5.
# DEBUG:Node 5 acted maliciously with contribution 9.637026349912858.
# DEBUG:Node 6 acted maliciously with contribution 9.5.
# DEBUG:Node 7 acted maliciously with contribution 10.284723658704186.
# DEBUG:Node 8 acted maliciously with contribution 10.075245886357841.
# DEBUG:Node 9 acted maliciously with contribution 10.43820330176644.
# DEBUG:Node 10 acted maliciously with contribution 9.728140811208224.
# DEBUG:Node 11 acted maliciously with contribution 9.949850276386073.
# DEBUG:Node 12 acted maliciously with contribution 9.539212391626874.
# DEBUG:Node 13 acted maliciously with contribution 9.977462627884949.
# DEBUG:Node 14 acted maliciously with contribution 9.797064512816673.
# DEBUG:Node 15 acted maliciously with contribution 9.632923185938829.
# DEBUG:Node 16 acted maliciously with contribution 10.755084396144259.
# DEBUG:Node 17 acted maliciously with contribution 10.203430438103508.
# DEBUG:Node 18 acted maliciously with contribution 9.5.
# DEBUG:Node 19 acted maliciously with contribution 9.904750812815502.
# DEBUG:Node 20 acted maliciously with contribution 10.045138465945262.
# DEBUG:Node 21 acted maliciously with contribution 9.654349443486769.
# DEBUG:Node 22 acted maliciously with contribution 10.129419894416632.
# DEBUG:Node 23 acted maliciously with contribution 9.729667783415598.
# DEBUG:Node 24 acted maliciously with contribution 9.5.
# DEBUG:Node 25 acted maliciously with contribution 9.701593561348702.
# DEBUG:Node 26 acted maliciously with contribution 9.627778906783782.
# DEBUG:Node 27 acted maliciously with contribution 9.850956175421913.
# DEBUG:Node 28 acted maliciously with contribution 9.913793785087725.
# DEBUG:Node 29 acted maliciously with contribution 9.64964299716174.
# DEBUG:Node 30 acted maliciously with contribution 10.6642088515412.
# DEBUG:Node 31 acted maliciously with contribution 10.113756522208943.
# DEBUG:Node 32 acted maliciously with contribution 9.5.
# DEBUG:Node 33 acted maliciously with contribution 9.5.
# DEBUG:Node 34 acted maliciously with contribution 9.57253579520648.
# DEBUG:Node 35 acted maliciously with contribution 9.882258257057487.
# DEBUG:Node 36 acted maliciously with contribution 9.889373972654658.
# DEBUG:Node 37 acted maliciously with contribution 9.64647008105413.
# DEBUG:Node 38 acted maliciously with contribution 10.097801730448866.
# DEBUG:Node 39 acted maliciously with contribution 9.652901402674027.
# DEBUG:Node 40 acted maliciously with contribution 10.137311231311136.
# DEBUG:Node 41 acted maliciously with contribution 9.812047943390118.
# DEBUG:Node 42 acted maliciously with contribution 10.031422968436594.
# DEBUG:Node 43 acted maliciously with contribution 10.12081687735362.
# DEBUG:Node 44 acted maliciously with contribution 9.761010971831444.
# DEBUG:Node 45 acted maliciously with contribution 9.908376783578678.
# DEBUG:Node 46 acted maliciously with contribution 9.72756770569597.
# DEBUG:Node 47 acted maliciously with contribution 10.044706264931019.
# DEBUG:Node 48 acted maliciously with contribution 9.84582916482945.
# DEBUG:Node 49 acted maliciously with contribution 9.863338456008805.
# DEBUG:Node 50 acted maliciously with contribution 9.790364496817709.
# DEBUG:Node 51 acted maliciously with contribution 9.852357212979829.
# DEBUG:Node 52 acted maliciously with contribution 9.748970557812703.
# DEBUG:Node 53 acted maliciously with contribution 9.5.
# DEBUG:Node 54 acted maliciously with contribution 9.5.
# DEBUG:Node 55 acted maliciously with contribution 9.839693437432048.
# DEBUG:Node 56 acted maliciously with contribution 10.075253625764946.
# DEBUG:Node 57 acted maliciously with contribution 9.5.
# DEBUG:Node 58 acted maliciously with contribution 9.691517708102921.
# DEBUG:Node 59 acted maliciously with contribution 9.93543308725649.
# DEBUG:Node 60 acted maliciously with contribution 9.770281423955211.
# DEBUG:Node 61 acted maliciously with contribution 9.645374870083405.
# DEBUG:Node 62 acted maliciously with contribution 9.5.
# DEBUG:Node 63 acted maliciously with contribution 9.877977652092648.
# DEBUG:Node 64 acted maliciously with contribution 9.983006053883749.
# DEBUG:Node 65 acted maliciously with contribution 9.90855272131722.
# DEBUG:Node 66 acted maliciously with contribution 9.817874344129615.
# DEBUG:Node 67 acted maliciously with contribution 9.5.
# DEBUG:Node 68 acted maliciously with contribution 9.58017038876029.
# DEBUG:Node 69 acted maliciously with contribution 9.5.
# DEBUG:Node 70 acted maliciously with contribution 9.787904610979533.
# DEBUG:Node 71 acted maliciously with contribution 10.33953125722287.
# DEBUG:Node 72 acted maliciously with contribution 9.860976286283554.
# DEBUG:Node 73 acted maliciously with contribution 10.138293630630544.
# DEBUG:Node 74 acted maliciously with contribution 9.5.
# DEBUG:Node 75 acted maliciously with contribution 10.393854373051216.
# DEBUG:Node 76 acted maliciously with contribution 9.5.
# DEBUG:Node 77 acted maliciously with contribution 9.5.
# DEBUG:Node 78 acted maliciously with contribution 9.5.
# DEBUG:Node 79 acted maliciously with contribution 9.878312687107368.
# DEBUG:Node 80 acted maliciously with contribution 9.5.
# DEBUG:Node 81 acted maliciously with contribution 9.853632175450093.
# DEBUG:Node 82 acted maliciously with contribution 10.012550878654888.
# DEBUG:Node 83 acted maliciously with contribution 9.55577379290646.
# DEBUG:Node 84 acted maliciously with contribution 9.830708679456977.
# DEBUG:Node 85 acted maliciously with contribution 9.814081260490024.
# DEBUG:Node 86 acted maliciously with contribution 9.5.
# DEBUG:Node 87 acted maliciously with contribution 9.5.
# DEBUG:Node 88 acted maliciously with contribution 9.5.
# DEBUG:Node 89 acted maliciously with contribution 9.918544869762783.
# DEBUG:Node 90 acted maliciously with contribution 10.283600199583507.
# DEBUG:Node 91 acted maliciously with contribution 9.5.
# DEBUG:Node 92 acted maliciously with contribution 9.5.
# DEBUG:Node 93 acted maliciously with contribution 10.266454200653694.
# DEBUG:Node 94 acted maliciously with contribution 9.599823824306705.
# DEBUG:Node 95 acted maliciously with contribution 9.799442435175651.
# DEBUG:Node 96 acted maliciously with contribution 9.5.
# DEBUG:Node 97 acted maliciously with contribution 10.590103370677074.
# DEBUG:Node 98 acted maliciously with contribution 9.755024084147605.
# DEBUG:Node 99 acted maliciously with contribution 10.149221770252957.
# DEBUG:Node 100 acted maliciously with contribution 10.15943349885071.
# DEBUG:Node 101 acted normally with contribution 7.59.
# DEBUG:Node 102 acted normally with contribution 6.33.
# DEBUG:Node 103 acted normally with contribution 4.69.
# DEBUG:Node 104 acted normally with contribution 7.58.
# DEBUG:Node 105 acted normally with contribution 6.16.
# DEBUG:Node 106 acted normally with contribution 5.12.
# DEBUG:Node 107 acted normally with contribution 8.51.
# DEBUG:Node 108 acted normally with contribution 5.65.
# DEBUG:Node 109 acted normally with contribution 5.31.
# DEBUG:Node 110 acted normally with contribution 6.34.
# DEBUG:Node 111 acted normally with contribution 6.58.
# DEBUG:Node 112 acted normally with contribution 4.90.
# DEBUG:Node 113 acted normally with contribution 6.67.
# DEBUG:Node 114 acted normally with contribution 8.34.
# DEBUG:Node 115 acted normally with contribution 7.14.
# DEBUG:Node 116 acted normally with contribution 5.09.
# DEBUG:Node 117 acted normally with contribution 6.80.
# DEBUG:Node 118 acted normally with contribution 10.30.
# DEBUG:Node 119 acted normally with contribution 8.91.
# DEBUG:Node 120 acted normally with contribution 7.30.
# DEBUG:Node 121 acted normally with contribution 7.40.
# DEBUG:Node 122 acted normally with contribution 4.47.
# DEBUG:Node 123 acted normally with contribution 8.24.
# DEBUG:Node 124 acted normally with contribution 5.98.
# DEBUG:Node 125 acted normally with contribution 6.33.
# DEBUG:Node 126 acted normally with contribution 4.98.
# DEBUG:Node 127 acted normally with contribution 6.02.
# DEBUG:Node 128 acted normally with contribution 5.44.
# DEBUG:Node 129 acted normally with contribution 7.04.
# DEBUG:Node 130 acted normally with contribution 5.71.
# DEBUG:Node 131 acted normally with contribution 6.92.
# DEBUG:Node 132 acted normally with contribution 6.56.
# DEBUG:Node 133 acted normally with contribution 8.30.
# DEBUG:Node 134 acted normally with contribution 6.73.
# DEBUG:Node 135 acted normally with contribution 6.85.
# DEBUG:Node 136 acted normally with contribution 7.03.
# DEBUG:Node 137 acted normally with contribution 9.21.
# DEBUG:Node 138 acted normally with contribution 6.50.
# DEBUG:Node 139 acted normally with contribution 5.44.
# DEBUG:Node 140 acted normally with contribution 7.94.
# DEBUG:Node 141 acted normally with contribution 6.63.
# DEBUG:Node 142 acted normally with contribution 6.30.
# DEBUG:Node 143 acted normally with contribution 5.39.
# DEBUG:Node 144 acted normally with contribution 10.48.
# DEBUG:Node 145 acted normally with contribution 7.35.
# DEBUG:Node 146 acted normally with contribution 7.68.
# DEBUG:Node 147 acted normally with contribution 6.70.
# DEBUG:Node 148 acted normally with contribution 7.22.
# DEBUG:Node 149 acted normally with contribution 5.20.
# DEBUG:Node 150 acted normally with contribution 7.66.
# DEBUG:Node 151 acted normally with contribution 4.49.
# DEBUG:Node 152 acted normally with contribution 7.43.
# DEBUG:Node 153 acted normally with contribution 6.82.
# DEBUG:Node 154 acted normally with contribution 7.58.
# DEBUG:Node 155 acted normally with contribution 7.46.
# DEBUG:Node 156 acted normally with contribution 6.71.
# DEBUG:Node 157 acted normally with contribution 5.12.
# DEBUG:Node 158 acted normally with contribution 6.43.
# DEBUG:Node 159 acted normally with contribution 7.20.
# DEBUG:Node 160 acted normally with contribution 8.78.
# DEBUG:Node 161 acted normally with contribution 6.88.
# DEBUG:Node 162 acted normally with contribution 9.45.
# DEBUG:Node 163 acted normally with contribution 6.23.
# DEBUG:Node 164 acted normally with contribution 6.91.
# DEBUG:Node 165 acted normally with contribution 4.70.
# DEBUG:Node 166 acted normally with contribution 4.73.
# DEBUG:Node 167 acted normally with contribution 7.53.
# DEBUG:Node 168 acted normally with contribution 4.15.
# DEBUG:Node 169 acted normally with contribution 7.23.
# DEBUG:Node 170 acted normally with contribution 9.08.
# DEBUG:Node 171 acted normally with contribution 6.53.
# DEBUG:Node 172 acted normally with contribution 5.88.
# DEBUG:Node 173 acted normally with contribution 7.40.
# DEBUG:Node 174 acted normally with contribution 7.52.
# DEBUG:Node 175 acted normally with contribution 6.61.
# DEBUG:Node 176 acted normally with contribution 10.48.
# DEBUG:Node 177 acted normally with contribution 7.43.
# DEBUG:Node 178 acted normally with contribution 6.29.
# DEBUG:Node 179 acted normally with contribution 8.58.
# DEBUG:Node 180 acted normally with contribution 8.34.
# DEBUG:Node 181 acted normally with contribution 6.84.
# DEBUG:Node 182 acted normally with contribution 4.82.
# DEBUG:Node 183 acted normally with contribution 7.88.
# DEBUG:Node 184 acted normally with contribution 6.70.
# DEBUG:Node 185 acted normally with contribution 7.40.
# DEBUG:Node 186 acted normally with contribution 7.66.
# DEBUG:Node 187 acted normally with contribution 8.75.
# DEBUG:Node 188 acted normally with contribution 6.30.
# DEBUG:Node 189 acted normally with contribution 8.00.
# DEBUG:Node 190 acted normally with contribution 6.20.
# DEBUG:Node 191 acted normally with contribution 8.65.
# DEBUG:Node 192 acted normally with contribution 6.74.
# DEBUG:Node 193 acted normally with contribution 11.34.
# DEBUG:Node 194 acted normally with contribution 5.14.
# DEBUG:Node 195 acted normally with contribution 6.67.
# DEBUG:Node 196 acted normally with contribution 7.75.
# DEBUG:Node 197 acted normally with contribution 6.21.
# DEBUG:Node 198 acted normally with contribution 7.17.
# DEBUG:Node 199 acted normally with contribution 4.66.
# DEBUG:Node 200 acted normally with contribution 6.22.
# DEBUG:Node 201 acted normally with contribution 7.95.
# DEBUG:Node 202 acted normally with contribution 8.12.
# DEBUG:Node 203 acted normally with contribution 5.88.
# DEBUG:Node 204 acted normally with contribution 9.62.
# DEBUG:Node 205 acted normally with contribution 5.90.
# DEBUG:Node 206 acted normally with contribution 6.38.
# DEBUG:Node 207 acted normally with contribution 7.41.
# DEBUG:Node 208 acted normally with contribution 5.89.
# DEBUG:Node 209 acted normally with contribution 5.05.
# DEBUG:Node 210 acted normally with contribution 4.79.
# DEBUG:Node 211 acted normally with contribution 7.96.
# DEBUG:Node 212 acted normally with contribution 6.55.
# DEBUG:Node 213 acted normally with contribution 6.22.
# DEBUG:Node 214 acted normally with contribution 5.42.
# DEBUG:Node 215 acted normally with contribution 6.48.
# DEBUG:Node 216 acted normally with contribution 6.30.
# DEBUG:Node 217 acted normally with contribution 5.35.
# DEBUG:Node 218 acted normally with contribution 6.51.
# DEBUG:Node 219 acted normally with contribution 7.12.
# DEBUG:Node 220 acted normally with contribution 8.18.
# DEBUG:Node 221 acted normally with contribution 7.09.
# DEBUG:Node 222 acted normally with contribution 4.92.
# DEBUG:Node 223 acted normally with contribution 7.90.
# DEBUG:Node 224 acted normally with contribution 5.46.
# DEBUG:Node 225 acted normally with contribution 8.44.
# DEBUG:Node 226 acted normally with contribution 6.11.
# DEBUG:Node 227 acted normally with contribution 10.34.
# DEBUG:Node 228 acted normally with contribution 5.48.
# DEBUG:Node 229 acted normally with contribution 7.77.
# DEBUG:Node 230 acted normally with contribution 5.55.
# DEBUG:Node 231 acted normally with contribution 7.26.
# DEBUG:Node 232 acted normally with contribution 7.20.
# DEBUG:Node 233 acted normally with contribution 8.91.
# DEBUG:Node 234 acted normally with contribution 5.20.
# DEBUG:Node 235 acted normally with contribution 4.16.
# DEBUG:Node 236 acted normally with contribution 8.06.
# DEBUG:Node 237 acted normally with contribution 8.16.
# DEBUG:Node 238 acted normally with contribution 7.59.
# DEBUG:Node 239 acted normally with contribution 10.95.
# DEBUG:Node 240 acted normally with contribution 7.51.
# DEBUG:Node 241 acted normally with contribution 8.61.
# DEBUG:Node 242 acted normally with contribution 5.31.
# DEBUG:Node 243 acted normally with contribution 6.04.
# DEBUG:Node 244 acted normally with contribution 6.67.
# DEBUG:Node 245 acted normally with contribution 6.81.
# DEBUG:Node 246 acted normally with contribution 6.87.
# DEBUG:Node 247 acted normally with contribution 7.96.
# DEBUG:Node 248 acted normally with contribution 7.38.
# DEBUG:Node 249 acted normally with contribution 4.93.
# DEBUG:Node 250 acted normally with contribution 6.33.
# DEBUG:Node 251 acted normally with contribution 7.75.
# DEBUG:Node 252 acted normally with contribution 5.50.
# DEBUG:Node 253 acted normally with contribution 7.41.
# DEBUG:Node 254 acted normally with contribution 7.69.
# DEBUG:Node 255 acted normally with contribution 7.96.
# DEBUG:Node 256 acted normally with contribution 6.89.
# DEBUG:Node 257 acted normally with contribution 7.78.
# DEBUG:Node 258 acted normally with contribution 9.37.
# DEBUG:Node 259 acted normally with contribution 7.64.
# DEBUG:Node 260 acted normally with contribution 4.93.
# DEBUG:Node 261 acted normally with contribution 6.93.
# DEBUG:Node 262 acted normally with contribution 6.48.
# DEBUG:Node 263 acted normally with contribution 8.06.
# DEBUG:Node 264 acted normally with contribution 6.69.
# DEBUG:Node 265 acted normally with contribution 6.98.
# DEBUG:Node 266 acted normally with contribution 6.38.
# DEBUG:Node 267 acted normally with contribution 7.22.
# DEBUG:Node 268 acted normally with contribution 4.42.
# DEBUG:Node 269 acted normally with contribution 5.65.
# DEBUG:Node 270 acted normally with contribution 6.61.
# DEBUG:Node 271 acted normally with contribution 5.93.
# DEBUG:Node 272 acted normally with contribution 6.61.
# DEBUG:Node 273 acted normally with contribution 5.87.
# DEBUG:Node 274 acted normally with contribution 4.94.
# DEBUG:Node 275 acted normally with contribution 5.10.
# DEBUG:Node 276 acted normally with contribution 6.54.
# DEBUG:Node 277 acted normally with contribution 5.51.
# DEBUG:Node 278 acted normally with contribution 5.34.
# DEBUG:Node 279 acted normally with contribution 5.81.
# DEBUG:Node 280 acted normally with contribution 5.72.
# DEBUG:Node 281 acted normally with contribution 6.79.
# DEBUG:Node 282 acted normally with contribution 5.41.
# DEBUG:Node 283 acted normally with contribution 5.66.
# DEBUG:Node 284 acted normally with contribution 8.89.
# DEBUG:Node 285 acted normally with contribution 5.17.
# DEBUG:Node 286 acted normally with contribution 9.02.
# DEBUG:Node 287 acted normally with contribution 6.27.
# DEBUG:Node 288 acted normally with contribution 6.74.
# DEBUG:Node 289 acted normally with contribution 7.18.
# DEBUG:Node 290 acted normally with contribution 5.70.
# DEBUG:Node 291 acted normally with contribution 6.89.
# DEBUG:Node 292 acted normally with contribution 7.40.
# DEBUG:Node 293 acted normally with contribution 7.50.
# DEBUG:Node 294 acted normally with contribution 8.90.
# DEBUG:Node 295 acted normally with contribution 5.80.
# DEBUG:Node 296 acted normally with contribution 5.80.
# DEBUG:Node 297 acted normally with contribution 7.06.
# DEBUG:Node 298 acted normally with contribution 6.62.
# DEBUG:Node 299 acted normally with contribution 5.65.
# DEBUG:Node 300 acted normally with contribution 5.02.
# DEBUG:Node 301 acted normally with contribution 9.35.
# DEBUG:Node 302 acted normally with contribution 7.12.
# DEBUG:Node 303 acted normally with contribution 5.87.
# DEBUG:Node 304 acted normally with contribution 5.14.
# DEBUG:Node 305 acted normally with contribution 6.57.
# DEBUG:Node 306 acted normally with contribution 7.39.
# DEBUG:Node 307 acted normally with contribution 6.54.
# DEBUG:Node 308 acted normally with contribution 5.61.
# DEBUG:Node 309 acted normally with contribution 8.56.
# DEBUG:Node 310 acted normally with contribution 7.79.
# DEBUG:Node 311 acted normally with contribution 4.31.
# DEBUG:Node 312 acted normally with contribution 5.53.
# DEBUG:Node 313 acted normally with contribution 7.56.
# DEBUG:Node 314 acted normally with contribution 7.82.
# DEBUG:Node 315 acted normally with contribution 5.69.
# DEBUG:Node 316 acted normally with contribution 5.14.
# DEBUG:Node 317 acted normally with contribution 10.25.
# DEBUG:Node 318 acted normally with contribution 6.39.
# DEBUG:Node 319 acted normally with contribution 6.97.
# DEBUG:Node 320 acted normally with contribution 7.83.
# DEBUG:Node 321 acted normally with contribution 8.65.
# DEBUG:Node 322 acted normally with contribution 8.29.
# DEBUG:Node 323 acted normally with contribution 8.20.
# DEBUG:Node 324 acted normally with contribution 6.58.
# DEBUG:Node 325 acted normally with contribution 7.02.
# DEBUG:Node 326 acted normally with contribution 8.30.
# DEBUG:Node 327 acted normally with contribution 6.46.
# DEBUG:Node 328 acted normally with contribution 6.86.
# DEBUG:Node 329 acted normally with contribution 8.41.
# DEBUG:Node 330 acted normally with contribution 6.18.
# DEBUG:Node 331 acted normally with contribution 8.48.
# DEBUG:Node 332 acted normally with contribution 7.81.
# DEBUG:Node 333 acted normally with contribution 9.69.
# DEBUG:Node 334 acted normally with contribution 6.80.
# DEBUG:Node 335 acted normally with contribution 6.29.
# DEBUG:Node 336 acted normally with contribution 8.74.
# DEBUG:Node 337 acted normally with contribution 7.79.
# DEBUG:Node 338 acted normally with contribution 7.14.
# DEBUG:Node 339 acted normally with contribution 4.15.
# DEBUG:Node 340 acted normally with contribution 5.09.
# DEBUG:Node 341 acted normally with contribution 8.70.
# DEBUG:Node 342 acted normally with contribution 8.61.
# DEBUG:Node 343 acted normally with contribution 4.50.
# DEBUG:Node 344 acted normally with contribution 7.30.
# DEBUG:Node 345 acted normally with contribution 8.35.
# DEBUG:Node 346 acted normally with contribution 7.39.
# DEBUG:Node 347 acted normally with contribution 6.76.
# DEBUG:Node 348 acted normally with contribution 9.53.
# DEBUG:Node 349 acted normally with contribution 5.87.
# DEBUG:Node 350 acted normally with contribution 6.74.
# DEBUG:Node 351 acted normally with contribution 5.82.
# DEBUG:Node 352 acted normally with contribution 8.72.
# DEBUG:Node 353 acted normally with contribution 6.12.
# DEBUG:Node 354 acted normally with contribution 6.70.
# DEBUG:Node 355 acted normally with contribution 5.00.
# DEBUG:Node 356 acted normally with contribution 10.28.
# DEBUG:Node 357 acted normally with contribution 7.83.
# DEBUG:Node 358 acted normally with contribution 6.22.
# DEBUG:Node 359 acted normally with contribution 6.14.
# DEBUG:Node 360 acted normally with contribution 7.95.
# DEBUG:Node 361 acted normally with contribution 7.76.
# DEBUG:Node 362 acted normally with contribution 6.40.
# DEBUG:Node 363 acted normally with contribution 7.26.
# DEBUG:Node 364 acted normally with contribution 8.39.
# DEBUG:Node 365 acted normally with contribution 6.81.
# DEBUG:Node 366 acted normally with contribution 8.23.
# DEBUG:Node 367 acted normally with contribution 8.98.
# DEBUG:Node 368 acted normally with contribution 6.81.
# DEBUG:Node 369 acted normally with contribution 6.64.
# DEBUG:Node 370 acted normally with contribution 6.70.
# DEBUG:Node 371 acted normally with contribution 5.37.
# DEBUG:Node 372 acted normally with contribution 7.88.
# DEBUG:Node 373 acted normally with contribution 6.14.
# DEBUG:Node 374 acted normally with contribution 7.14.
# DEBUG:Node 375 acted normally with contribution 8.34.
# DEBUG:Node 376 acted normally with contribution 8.78.
# DEBUG:Node 377 acted normally with contribution 6.51.
# DEBUG:Node 378 acted normally with contribution 8.61.
# DEBUG:Node 379 acted normally with contribution 8.47.
# DEBUG:Node 380 acted normally with contribution 7.83.
# DEBUG:Node 381 acted normally with contribution 4.88.
# DEBUG:Node 382 acted normally with contribution 5.69.
# DEBUG:Node 383 acted normally with contribution 6.76.
# DEBUG:Node 384 acted normally with contribution 7.07.
# DEBUG:Node 385 acted normally with contribution 9.65.
# DEBUG:Node 386 acted normally with contribution 5.14.
# DEBUG:Node 387 acted normally with contribution 5.54.
# DEBUG:Node 388 acted normally with contribution 10.87.
# DEBUG:Node 389 acted normally with contribution 6.22.
# DEBUG:Node 390 acted normally with contribution 8.98.
# DEBUG:Node 391 acted normally with contribution 7.04.
# DEBUG:Node 392 acted normally with contribution 7.64.
# DEBUG:Node 393 acted normally with contribution 6.02.
# DEBUG:Node 394 acted normally with contribution 7.48.
# DEBUG:Node 395 acted normally with contribution 7.58.
# DEBUG:Node 396 acted normally with contribution 6.89.
# DEBUG:Node 397 acted normally with contribution 6.80.
# DEBUG:Node 398 acted normally with contribution 8.35.
# DEBUG:Node 399 acted normally with contribution 6.99.
# DEBUG:Node 400 acted normally with contribution 5.88.
# DEBUG:Node 401 acted normally with contribution 6.07.
# DEBUG:Node 402 acted normally with contribution 5.83.
# DEBUG:Node 403 acted normally with contribution 8.35.
# DEBUG:Node 404 acted normally with contribution 6.81.
# DEBUG:Node 405 acted normally with contribution 7.55.
# DEBUG:Node 406 acted normally with contribution 6.93.
# DEBUG:Node 407 acted normally with contribution 5.39.
# DEBUG:Node 408 acted normally with contribution 7.79.
# DEBUG:Node 409 acted normally with contribution 4.52.
# DEBUG:Node 410 acted normally with contribution 7.34.
# DEBUG:Node 411 acted normally with contribution 6.20.
# DEBUG:Node 412 acted normally with contribution 8.09.
# DEBUG:Node 413 acted normally with contribution 10.09.
# DEBUG:Node 414 acted normally with contribution 5.21.
# DEBUG:Node 415 acted normally with contribution 7.90.
# DEBUG:Node 416 acted normally with contribution 6.98.
# DEBUG:Node 417 acted normally with contribution 6.89.
# DEBUG:Node 418 acted normally with contribution 7.90.
# DEBUG:Node 419 acted normally with contribution 8.22.
# DEBUG:Node 420 acted normally with contribution 8.43.
# DEBUG:Node 421 acted normally with contribution 7.18.
# DEBUG:Node 422 acted normally with contribution 8.41.
# DEBUG:Node 423 acted normally with contribution 6.76.
# DEBUG:Node 424 acted normally with contribution 7.91.
# DEBUG:Node 425 acted normally with contribution 8.74.
# DEBUG:Node 426 acted normally with contribution 5.39.
# DEBUG:Node 427 acted normally with contribution 8.70.
# DEBUG:Node 428 acted normally with contribution 5.03.
# DEBUG:Node 429 acted normally with contribution 6.30.
# DEBUG:Node 430 acted normally with contribution 7.77.
# DEBUG:Node 431 acted normally with contribution 7.90.
# DEBUG:Node 432 acted normally with contribution 8.00.
# DEBUG:Node 433 acted normally with contribution 5.15.
# DEBUG:Node 434 acted normally with contribution 7.58.
# DEBUG:Node 435 acted normally with contribution 6.12.
# DEBUG:Node 436 acted normally with contribution 6.12.
# DEBUG:Node 437 acted normally with contribution 8.34.
# DEBUG:Node 438 acted normally with contribution 6.86.
# DEBUG:Node 439 acted normally with contribution 6.49.
# DEBUG:Node 440 acted normally with contribution 7.32.
# DEBUG:Node 441 acted normally with contribution 7.50.
# DEBUG:Node 442 acted normally with contribution 5.05.
# DEBUG:Node 443 acted normally with contribution 6.89.
# DEBUG:Node 444 acted normally with contribution 9.27.
# DEBUG:Node 445 acted normally with contribution 6.61.
# DEBUG:Node 446 acted normally with contribution 7.29.
# DEBUG:Node 447 acted normally with contribution 7.07.
# DEBUG:Node 448 acted normally with contribution 6.42.
# DEBUG:Node 449 acted normally with contribution 6.02.
# DEBUG:Node 450 acted normally with contribution 4.99.
# DEBUG:Node 451 acted normally with contribution 7.01.
# DEBUG:Node 452 acted normally with contribution 7.73.
# DEBUG:Node 453 acted normally with contribution 7.11.
# DEBUG:Node 454 acted normally with contribution 6.11.
# DEBUG:Node 455 acted normally with contribution 7.15.
# DEBUG:Node 456 acted normally with contribution 7.36.
# DEBUG:Node 457 acted normally with contribution 6.49.
# DEBUG:Node 458 acted normally with contribution 9.71.
# DEBUG:Node 459 acted normally with contribution 7.48.
# DEBUG:Node 460 acted normally with contribution 8.60.
# DEBUG:Node 461 acted normally with contribution 7.28.
# DEBUG:Node 462 acted normally with contribution 7.32.
# DEBUG:Node 463 acted normally with contribution 6.07.
# DEBUG:Node 464 acted normally with contribution 6.96.
# DEBUG:Node 465 acted normally with contribution 6.06.
# DEBUG:Node 466 acted normally with contribution 7.32.
# DEBUG:Node 467 acted normally with contribution 9.37.
# DEBUG:Node 468 acted normally with contribution 8.46.
# DEBUG:Node 469 acted normally with contribution 8.20.
# DEBUG:Node 470 acted normally with contribution 8.22.
# DEBUG:Node 471 acted normally with contribution 7.43.
# DEBUG:Node 472 acted normally with contribution 5.03.
# DEBUG:Node 473 acted normally with contribution 7.28.
# DEBUG:Node 474 acted normally with contribution 6.05.
# DEBUG:Node 475 acted normally with contribution 6.93.
# DEBUG:Node 476 acted normally with contribution 7.68.
# DEBUG:Node 477 acted normally with contribution 5.96.
# DEBUG:Node 478 acted normally with contribution 8.43.
# DEBUG:Node 479 acted normally with contribution 7.48.
# DEBUG:Node 480 acted normally with contribution 8.45.
# DEBUG:Node 481 acted normally with contribution 5.55.
# DEBUG:Node 482 acted normally with contribution 5.08.
# DEBUG:Node 483 acted normally with contribution 5.80.
# DEBUG:Node 484 acted normally with contribution 8.81.
# DEBUG:Node 485 acted normally with contribution 6.43.
# DEBUG:Node 486 acted normally with contribution 7.29.
# DEBUG:Node 487 acted normally with contribution 8.37.
# DEBUG:Node 488 acted normally with contribution 7.82.
# DEBUG:Node 489 acted normally with contribution 8.74.
# DEBUG:Node 490 acted normally with contribution 7.12.
# DEBUG:Node 491 acted normally with contribution 6.22.
# DEBUG:Node 492 acted normally with contribution 6.42.
# DEBUG:Node 493 acted normally with contribution 5.87.
# DEBUG:Node 494 acted normally with contribution 9.44.
# DEBUG:Node 495 acted normally with contribution 5.83.
# DEBUG:Node 496 acted normally with contribution 7.81.
# DEBUG:Node 497 acted normally with contribution 6.00.
# DEBUG:Node 498 acted normally with contribution 6.01.
# DEBUG:Node 499 acted normally with contribution 10.05.
# DEBUG:Node 500 acted normally with contribution 7.11.
# DEBUG:Node 501 acted normally with contribution 7.05.
# DEBUG:Node 502 acted normally with contribution 6.55.
# DEBUG:Node 503 acted normally with contribution 6.54.
# DEBUG:Node 504 acted normally with contribution 8.98.
# DEBUG:Node 505 acted normally with contribution 5.33.
# DEBUG:Node 506 acted normally with contribution 7.92.
# DEBUG:Node 507 acted normally with contribution 6.20.
# DEBUG:Node 508 acted normally with contribution 8.49.
# DEBUG:Node 509 acted normally with contribution 7.89.
# DEBUG:Node 510 acted normally with contribution 6.88.
# DEBUG:Node 511 acted normally with contribution 5.12.
# DEBUG:Node 512 acted normally with contribution 5.93.
# DEBUG:Node 513 acted normally with contribution 7.59.
# DEBUG:Node 514 acted normally with contribution 5.97.
# DEBUG:Node 515 acted normally with contribution 7.77.
# DEBUG:Node 516 acted normally with contribution 7.18.
# DEBUG:Node 517 acted normally with contribution 8.00.
# DEBUG:Node 518 acted normally with contribution 6.27.
# DEBUG:Node 519 acted normally with contribution 6.27.
# DEBUG:Node 520 acted normally with contribution 6.45.
# DEBUG:Node 521 acted normally with contribution 5.68.
# DEBUG:Node 522 acted normally with contribution 6.76.
# DEBUG:Node 523 acted normally with contribution 4.94.
# DEBUG:Node 524 acted normally with contribution 6.12.
# DEBUG:Node 525 acted normally with contribution 9.47.
# DEBUG:Node 526 acted normally with contribution 9.12.
# DEBUG:Node 527 acted normally with contribution 7.21.
# DEBUG:Node 528 acted normally with contribution 7.98.
# DEBUG:Node 529 acted normally with contribution 6.01.
# DEBUG:Node 530 acted normally with contribution 5.24.
# DEBUG:Node 531 acted normally with contribution 8.55.
# DEBUG:Node 532 acted normally with contribution 5.47.
# DEBUG:Node 533 acted normally with contribution 6.25.
# DEBUG:Node 534 acted normally with contribution 7.84.
# DEBUG:Node 535 acted normally with contribution 11.78.
# DEBUG:Node 536 acted normally with contribution 6.01.
# DEBUG:Node 537 acted normally with contribution 7.10.
# DEBUG:Node 538 acted normally with contribution 8.01.
# DEBUG:Node 539 acted normally with contribution 9.54.
# DEBUG:Node 540 acted normally with contribution 7.02.
# DEBUG:Node 541 acted normally with contribution 7.32.
# DEBUG:Node 542 acted normally with contribution 8.83.
# DEBUG:Node 543 acted normally with contribution 8.68.
# DEBUG:Node 544 acted normally with contribution 6.14.
# DEBUG:Node 545 acted normally with contribution 6.22.
# DEBUG:Node 546 acted normally with contribution 6.35.
# DEBUG:Node 547 acted normally with contribution 9.28.
# DEBUG:Node 548 acted normally with contribution 5.24.
# DEBUG:Node 549 acted normally with contribution 6.84.
# DEBUG:Node 550 acted normally with contribution 8.28.
# DEBUG:Node 551 acted normally with contribution 6.63.
# DEBUG:Node 552 acted normally with contribution 6.06.
# DEBUG:Node 553 acted normally with contribution 6.44.
# DEBUG:Node 554 acted normally with contribution 7.08.
# DEBUG:Node 555 acted normally with contribution 7.37.
# DEBUG:Node 556 acted normally with contribution 8.21.
# DEBUG:Node 557 acted normally with contribution 6.33.
# DEBUG:Node 558 acted normally with contribution 6.55.
# DEBUG:Node 559 acted normally with contribution 6.39.
# DEBUG:Node 560 acted normally with contribution 10.20.
# DEBUG:Node 561 acted normally with contribution 7.04.
# DEBUG:Node 562 acted normally with contribution 6.91.
# DEBUG:Node 563 acted normally with contribution 7.20.
# DEBUG:Node 564 acted normally with contribution 7.34.
# DEBUG:Node 565 acted normally with contribution 5.62.
# DEBUG:Node 566 acted normally with contribution 7.55.
# DEBUG:Node 567 acted normally with contribution 4.95.
# DEBUG:Node 568 acted normally with contribution 7.46.
# DEBUG:Node 569 acted normally with contribution 5.97.
# DEBUG:Node 570 acted normally with contribution 6.69.
# DEBUG:Node 571 acted normally with contribution 6.22.
# DEBUG:Node 572 acted normally with contribution 7.99.
# DEBUG:Node 573 acted normally with contribution 7.46.
# DEBUG:Node 574 acted normally with contribution 7.70.
# DEBUG:Node 575 acted normally with contribution 8.09.
# DEBUG:Node 576 acted normally with contribution 8.08.
# DEBUG:Node 577 acted normally with contribution 5.43.
# DEBUG:Node 578 acted normally with contribution 7.96.
# DEBUG:Node 579 acted normally with contribution 9.72.
# DEBUG:Node 580 acted normally with contribution 9.51.
# DEBUG:Node 581 acted normally with contribution 6.61.
# DEBUG:Node 582 acted normally with contribution 7.89.
# DEBUG:Node 583 acted normally with contribution 5.59.
# DEBUG:Node 584 acted normally with contribution 5.25.
# DEBUG:Node 585 acted normally with contribution 7.38.
# DEBUG:Node 586 acted normally with contribution 3.77.
# DEBUG:Node 587 acted normally with contribution 5.36.
# DEBUG:Node 588 acted normally with contribution 6.44.
# DEBUG:Node 589 acted normally with contribution 9.39.
# DEBUG:Node 590 acted normally with contribution 7.58.
# DEBUG:Node 591 acted normally with contribution 7.35.
# DEBUG:Node 592 acted normally with contribution 4.95.
# DEBUG:Node 593 acted normally with contribution 5.65.
# DEBUG:Node 594 acted normally with contribution 9.61.
# DEBUG:Node 595 acted normally with contribution 8.90.
# DEBUG:Node 596 acted normally with contribution 9.03.
# DEBUG:Node 597 acted normally with contribution 5.09.
# DEBUG:Node 598 acted normally with contribution 7.12.
# DEBUG:Node 599 acted normally with contribution 5.82.
# DEBUG:Node 600 acted normally with contribution 10.16.
# DEBUG:Node 601 acted normally with contribution 6.99.
# DEBUG:Node 602 acted normally with contribution 6.34.
# DEBUG:Node 603 acted normally with contribution 6.60.
# DEBUG:Node 604 acted normally with contribution 6.95.
# DEBUG:Node 605 acted normally with contribution 10.35.
# DEBUG:Node 606 acted normally with contribution 6.72.
# DEBUG:Node 607 acted normally with contribution 9.30.
# DEBUG:Node 608 acted normally with contribution 8.92.
# DEBUG:Node 609 acted normally with contribution 7.48.
# DEBUG:Node 610 acted normally with contribution 7.10.
# DEBUG:Node 611 acted normally with contribution 7.15.
# DEBUG:Node 612 acted normally with contribution 7.96.
# DEBUG:Node 613 acted normally with contribution 4.89.
# DEBUG:Node 614 acted normally with contribution 6.76.
# DEBUG:Node 615 acted normally with contribution 6.61.
# DEBUG:Node 616 acted normally with contribution 5.19.
# DEBUG:Node 617 acted normally with contribution 6.41.
# DEBUG:Node 618 acted normally with contribution 7.85.
# DEBUG:Node 619 acted normally with contribution 5.33.
# DEBUG:Node 620 acted normally with contribution 6.42.
# DEBUG:Node 621 acted normally with contribution 7.27.
# DEBUG:Node 622 acted normally with contribution 7.20.
# DEBUG:Node 623 acted normally with contribution 6.65.
# DEBUG:Node 624 acted normally with contribution 7.89.
# DEBUG:Node 625 acted normally with contribution 5.94.
# DEBUG:Node 626 acted normally with contribution 9.40.
# DEBUG:Node 627 acted normally with contribution 6.93.
# DEBUG:Node 628 acted normally with contribution 9.19.
# DEBUG:Node 629 acted normally with contribution 6.43.
# DEBUG:Node 630 acted normally with contribution 6.01.
# DEBUG:Node 631 acted normally with contribution 6.23.
# DEBUG:Node 632 acted normally with contribution 6.79.
# DEBUG:Node 633 acted normally with contribution 9.49.
# DEBUG:Node 634 acted normally with contribution 6.27.
# DEBUG:Node 635 acted normally with contribution 7.03.
# DEBUG:Node 636 acted normally with contribution 6.03.
# DEBUG:Node 637 acted normally with contribution 7.46.
# DEBUG:Node 638 acted normally with contribution 5.46.
# DEBUG:Node 639 acted normally with contribution 5.98.
# DEBUG:Node 640 acted normally with contribution 8.72.
# DEBUG:Node 641 acted normally with contribution 9.33.
# DEBUG:Node 642 acted normally with contribution 6.41.
# DEBUG:Node 643 acted normally with contribution 5.56.
# DEBUG:Node 644 acted normally with contribution 11.11.
# DEBUG:Node 645 acted normally with contribution 8.03.
# DEBUG:Node 646 acted normally with contribution 10.04.
# DEBUG:Node 647 acted normally with contribution 5.65.
# DEBUG:Node 648 acted normally with contribution 7.64.
# DEBUG:Node 649 acted normally with contribution 4.65.
# DEBUG:Node 650 acted normally with contribution 4.31.
# DEBUG:Node 651 acted normally with contribution 10.01.
# DEBUG:Node 652 acted normally with contribution 7.28.
# DEBUG:Node 653 acted normally with contribution 9.40.
# DEBUG:Node 654 acted normally with contribution 8.31.
# DEBUG:Node 655 acted normally with contribution 8.50.
# DEBUG:Node 656 acted normally with contribution 8.09.
# DEBUG:Node 657 acted normally with contribution 7.13.
# DEBUG:Node 658 acted normally with contribution 7.74.
# DEBUG:Node 659 acted normally with contribution 6.18.
# DEBUG:Node 660 acted normally with contribution 5.46.
# DEBUG:Node 661 acted normally with contribution 5.93.
# DEBUG:Node 662 acted normally with contribution 6.17.
# DEBUG:Node 663 acted normally with contribution 6.36.
# DEBUG:Node 664 acted normally with contribution 5.60.
# DEBUG:Node 665 acted normally with contribution 5.99.
# DEBUG:Node 666 acted normally with contribution 6.83.
# DEBUG:Node 667 acted normally with contribution 6.94.
# DEBUG:Node 668 acted normally with contribution 7.34.
# DEBUG:Node 669 acted normally with contribution 6.34.
# DEBUG:Node 670 acted normally with contribution 10.03.
# DEBUG:Node 671 acted normally with contribution 5.96.
# DEBUG:Node 672 acted normally with contribution 8.10.
# DEBUG:Node 673 acted normally with contribution 6.57.
# DEBUG:Node 674 acted normally with contribution 6.96.
# DEBUG:Node 675 acted normally with contribution 6.27.
# DEBUG:Node 676 acted normally with contribution 6.19.
# DEBUG:Node 677 acted normally with contribution 7.95.
# DEBUG:Node 678 acted normally with contribution 8.15.
# DEBUG:Node 679 acted normally with contribution 7.60.
# DEBUG:Node 680 acted normally with contribution 4.42.
# DEBUG:Node 681 acted normally with contribution 3.85.
# DEBUG:Node 682 acted normally with contribution 7.13.
# DEBUG:Node 683 acted normally with contribution 8.51.
# DEBUG:Node 684 acted normally with contribution 7.95.
# DEBUG:Node 685 acted normally with contribution 5.36.
# DEBUG:Node 686 acted normally with contribution 8.59.
# DEBUG:Node 687 acted normally with contribution 6.75.
# DEBUG:Node 688 acted normally with contribution 6.61.
# DEBUG:Node 689 acted normally with contribution 6.58.
# DEBUG:Node 690 acted normally with contribution 8.84.
# DEBUG:Node 691 acted normally with contribution 8.58.
# DEBUG:Node 692 acted normally with contribution 8.49.
# DEBUG:Node 693 acted normally with contribution 7.72.
# DEBUG:Node 694 acted normally with contribution 6.78.
# DEBUG:Node 695 acted normally with contribution 6.06.
# DEBUG:Node 696 acted normally with contribution 7.82.
# DEBUG:Node 697 acted normally with contribution 6.84.
# DEBUG:Node 698 acted normally with contribution 5.98.
# DEBUG:Node 699 acted normally with contribution 6.43.
# DEBUG:Node 700 acted normally with contribution 7.43.
# DEBUG:Node 701 acted normally with contribution 6.43.
# DEBUG:Node 702 acted normally with contribution 8.31.
# DEBUG:Node 703 acted normally with contribution 10.28.
# DEBUG:Node 704 acted normally with contribution 7.96.
# DEBUG:Node 705 acted normally with contribution 6.69.
# DEBUG:Node 706 acted normally with contribution 7.13.
# DEBUG:Node 707 acted normally with contribution 7.27.
# DEBUG:Node 708 acted normally with contribution 6.81.
# DEBUG:Node 709 acted normally with contribution 6.59.
# DEBUG:Node 710 acted normally with contribution 6.14.
# DEBUG:Node 711 acted normally with contribution 7.71.
# DEBUG:Node 712 acted normally with contribution 8.11.
# DEBUG:Node 713 acted normally with contribution 6.51.
# DEBUG:Node 714 acted normally with contribution 5.22.
# DEBUG:Node 715 acted normally with contribution 7.08.
# DEBUG:Node 716 acted normally with contribution 6.86.
# DEBUG:Node 717 acted normally with contribution 6.56.
# DEBUG:Node 718 acted normally with contribution 4.67.
# DEBUG:Node 719 acted normally with contribution 6.81.
# DEBUG:Node 720 acted normally with contribution 4.18.
# DEBUG:Node 721 acted normally with contribution 5.65.
# DEBUG:Node 722 acted normally with contribution 5.71.
# DEBUG:Node 723 acted normally with contribution 5.66.
# DEBUG:Node 724 acted normally with contribution 7.94.
# DEBUG:Node 725 acted normally with contribution 7.09.
# DEBUG:Node 726 acted normally with contribution 6.20.
# DEBUG:Node 727 acted normally with contribution 6.28.
# DEBUG:Node 728 acted normally with contribution 9.00.
# DEBUG:Node 729 acted normally with contribution 7.10.
# DEBUG:Node 730 acted normally with contribution 3.99.
# DEBUG:Node 731 acted normally with contribution 5.86.
# DEBUG:Node 732 acted normally with contribution 5.43.
# DEBUG:Node 733 acted normally with contribution 8.09.
# DEBUG:Node 734 acted normally with contribution 6.39.
# DEBUG:Node 735 acted normally with contribution 6.48.
# DEBUG:Node 736 acted normally with contribution 7.55.
# DEBUG:Node 737 acted normally with contribution 5.74.
# DEBUG:Node 738 acted normally with contribution 6.14.
# DEBUG:Node 739 acted normally with contribution 6.41.
# DEBUG:Node 740 acted normally with contribution 6.49.
# DEBUG:Node 741 acted normally with contribution 6.11.
# DEBUG:Node 742 acted normally with contribution 4.66.
# DEBUG:Node 743 acted normally with contribution 7.71.
# DEBUG:Node 744 acted normally with contribution 6.90.
# DEBUG:Node 745 acted normally with contribution 6.27.
# DEBUG:Node 746 acted normally with contribution 6.43.
# DEBUG:Node 747 acted normally with contribution 11.27.
# DEBUG:Node 748 acted normally with contribution 5.74.
# DEBUG:Node 749 acted normally with contribution 5.75.
# DEBUG:Node 750 acted normally with contribution 5.95.
# DEBUG:Node 751 acted normally with contribution 8.47.
# DEBUG:Node 752 acted normally with contribution 7.73.
# DEBUG:Node 753 acted normally with contribution 6.44.
# DEBUG:Node 754 acted normally with contribution 7.27.
# DEBUG:Node 755 acted normally with contribution 9.05.
# DEBUG:Node 756 acted normally with contribution 8.32.
# DEBUG:Node 757 acted normally with contribution 5.78.
# DEBUG:Node 758 acted normally with contribution 7.11.
# DEBUG:Node 759 acted normally with contribution 8.07.
# DEBUG:Node 760 acted normally with contribution 6.48.
# DEBUG:Node 761 acted normally with contribution 6.69.
# DEBUG:Node 762 acted normally with contribution 7.64.
# DEBUG:Node 763 acted normally with contribution 5.18.
# DEBUG:Node 764 acted normally with contribution 5.85.
# DEBUG:Node 765 acted normally with contribution 7.15.
# DEBUG:Node 766 acted normally with contribution 5.99.
# DEBUG:Node 767 acted normally with contribution 9.86.
# DEBUG:Node 768 acted normally with contribution 7.56.
# DEBUG:Node 769 acted normally with contribution 6.88.
# DEBUG:Node 770 acted normally with contribution 7.18.
# DEBUG:Node 771 acted normally with contribution 8.23.
# DEBUG:Node 772 acted normally with contribution 6.20.
# DEBUG:Node 773 acted normally with contribution 6.91.
# DEBUG:Node 774 acted normally with contribution 7.16.
# DEBUG:Node 775 acted normally with contribution 5.25.
# DEBUG:Node 776 acted normally with contribution 7.92.
# DEBUG:Node 777 acted normally with contribution 8.15.
# DEBUG:Node 778 acted normally with contribution 5.25.
# DEBUG:Node 779 acted normally with contribution 7.70.
# DEBUG:Node 780 acted normally with contribution 6.74.
# DEBUG:Node 781 acted normally with contribution 6.52.
# DEBUG:Node 782 acted normally with contribution 5.74.
# DEBUG:Node 783 acted normally with contribution 6.96.
# DEBUG:Node 784 acted normally with contribution 5.84.
# DEBUG:Node 785 acted normally with contribution 4.72.
# DEBUG:Node 786 acted normally with contribution 5.39.
# DEBUG:Node 787 acted normally with contribution 7.50.
# DEBUG:Node 788 acted normally with contribution 5.95.
# DEBUG:Node 789 acted normally with contribution 6.42.
# DEBUG:Node 790 acted normally with contribution 7.11.
# DEBUG:Node 791 acted normally with contribution 5.89.
# DEBUG:Node 792 acted normally with contribution 9.89.
# DEBUG:Node 793 acted normally with contribution 5.47.
# DEBUG:Node 794 acted normally with contribution 5.10.
# DEBUG:Node 795 acted normally with contribution 5.03.
# DEBUG:Node 796 acted normally with contribution 8.42.
# DEBUG:Node 797 acted normally with contribution 6.53.
# DEBUG:Node 798 acted normally with contribution 6.59.
# DEBUG:Node 799 acted normally with contribution 8.13.
# DEBUG:Node 800 acted normally with contribution 8.35.
# DEBUG:Node 801 acted normally with contribution 5.38.
# DEBUG:Node 802 acted normally with contribution 8.52.
# DEBUG:Node 803 acted normally with contribution 7.69.
# DEBUG:Node 804 acted normally with contribution 8.82.
# DEBUG:Node 805 acted normally with contribution 6.14.
# DEBUG:Node 806 acted normally with contribution 6.10.
# DEBUG:Node 807 acted normally with contribution 5.35.
# DEBUG:Node 808 acted normally with contribution 8.80.
# DEBUG:Node 809 acted normally with contribution 5.02.
# DEBUG:Node 810 acted normally with contribution 6.56.
# DEBUG:Node 811 acted normally with contribution 9.92.
# DEBUG:Node 812 acted normally with contribution 6.74.
# DEBUG:Node 813 acted normally with contribution 6.15.
# DEBUG:Node 814 acted normally with contribution 7.84.
# DEBUG:Node 815 acted normally with contribution 4.53.
# DEBUG:Node 816 acted normally with contribution 8.17.
# DEBUG:Node 817 acted normally with contribution 6.29.
# DEBUG:Node 818 acted normally with contribution 6.61.
# DEBUG:Node 819 acted normally with contribution 7.53.
# DEBUG:Node 820 acted normally with contribution 5.64.
# DEBUG:Node 821 acted normally with contribution 7.84.
# DEBUG:Node 822 acted normally with contribution 8.66.
# DEBUG:Node 823 acted normally with contribution 5.66.
# DEBUG:Node 824 acted normally with contribution 4.42.
# DEBUG:Node 825 acted normally with contribution 9.20.
# DEBUG:Node 826 acted normally with contribution 9.64.
# DEBUG:Node 827 acted normally with contribution 6.77.
# DEBUG:Node 828 acted normally with contribution 7.49.
# DEBUG:Node 829 acted normally with contribution 5.67.
# DEBUG:Node 830 acted normally with contribution 7.47.
# DEBUG:Node 831 acted normally with contribution 6.45.
# DEBUG:Node 832 acted normally with contribution 6.78.
# DEBUG:Node 833 acted normally with contribution 6.49.
# DEBUG:Node 834 acted normally with contribution 6.33.
# DEBUG:Node 835 acted normally with contribution 6.63.
# DEBUG:Node 836 acted normally with contribution 6.93.
# DEBUG:Node 837 acted normally with contribution 5.81.
# DEBUG:Node 838 acted normally with contribution 5.38.
# DEBUG:Node 839 acted normally with contribution 6.44.
# DEBUG:Node 840 acted normally with contribution 6.36.
# DEBUG:Node 841 acted normally with contribution 6.09.
# DEBUG:Node 842 acted normally with contribution 5.31.
# DEBUG:Node 843 acted normally with contribution 6.66.
# DEBUG:Node 844 acted normally with contribution 5.78.
# DEBUG:Node 845 acted normally with contribution 7.96.
# DEBUG:Node 846 acted normally with contribution 8.26.
# DEBUG:Node 847 acted normally with contribution 6.96.
# DEBUG:Node 848 acted normally with contribution 8.62.
# DEBUG:Node 849 acted normally with contribution 4.59.
# DEBUG:Node 850 acted normally with contribution 6.05.
# DEBUG:Node 851 acted normally with contribution 4.68.
# DEBUG:Node 852 acted normally with contribution 5.82.
# DEBUG:Node 853 acted normally with contribution 7.17.
# DEBUG:Node 854 acted normally with contribution 6.96.
# DEBUG:Node 855 acted normally with contribution 5.91.
# DEBUG:Node 856 acted normally with contribution 6.13.
# DEBUG:Node 857 acted normally with contribution 6.60.
# DEBUG:Node 858 acted normally with contribution 7.79.
# DEBUG:Node 859 acted normally with contribution 7.48.
# ...
# DEBUG:Node 817 acted normally with contribution 6.13.
# DEBUG:Node 818 acted normally with contribution 8.85.
# DEBUG:Node 819 acted normally with contribution 6.26.
# DEBUG:Node 820 acted normally with contribution 8.37.
# DEBUG:Node 821 acted normally with contribution 6.28.
# DEBUG:Node 822 acted normally with contribution 4.78.
# DEBUG:Node 823 acted normally with contribution 11.54.
# DEBUG:Node 824 acted normally with contribution 4.62.
# DEBUG:Node 825 acted normally with contribution 7.38.
# DEBUG:Node 826 acted normally with contribution 6.02.
# DEBUG:Node 827 acted normally with contribution 6.48.
# DEBUG:Node 828 acted normally with contribution 7.25.
# DEBUG:Node 829 acted normally with contribution 10.26.
# DEBUG:Node 830 acted normally with contribution 5.63.
# DEBUG:Node 831 acted normally with contribution 7.45.
# DEBUG:Node 832 acted normally with contribution 9.23.
# DEBUG:Node 833 acted normally with contribution 8.34.
# DEBUG:Node 834 acted normally with contribution 9.52.
# DEBUG:Node 835 acted normally with contribution 6.99.
# DEBUG:Node 836 acted normally with contribution 8.13.
# DEBUG:Node 837 acted normally with contribution 7.36.
# DEBUG:Node 838 acted normally with contribution 7.82.
# DEBUG:Node 839 acted normally with contribution 8.77.
# DEBUG:Node 840 acted normally with contribution 6.61.
# DEBUG:Node 841 acted normally with contribution 6.32.
# DEBUG:Node 842 acted normally with contribution 6.82.
# DEBUG:Node 843 acted normally with contribution 6.99.
# DEBUG:Node 844 acted normally with contribution 4.54.
# DEBUG:Node 845 acted normally with contribution 8.18.
# DEBUG:Node 846 acted normally with contribution 8.06.
# DEBUG:Node 847 acted normally with contribution 6.71.
# DEBUG:Node 848 acted normally with contribution 6.61.
# DEBUG:Node 849 acted normally with contribution 6.49.
# DEBUG:Node 850 acted normally with contribution 6.04.
# DEBUG:Node 851 acted normally with contribution 7.71.
# DEBUG:Node 852 acted normally with contribution 9.19.
# DEBUG:Node 853 acted normally with contribution 5.05.
# DEBUG:Node 854 acted normally with contribution 6.95.
# DEBUG:Node 855 acted normally with contribution 6.38.
# DEBUG:Node 856 acted normally with contribution 8.72.
# DEBUG:Node 857 acted normally with contribution 8.42.
# DEBUG:Node 858 acted normally with contribution 8.50.
# DEBUG:Node 859 acted normally with contribution 7.31.
# DEBUG:Node 860 acted normally with contribution 9.30.
# DEBUG:Node 861 acted normally with contribution 7.08.
# DEBUG:Node 862 acted normally with contribution 10.04.
# DEBUG:Node 863 acted normally with contribution 6.16.
# DEBUG:Node 864 acted normally with contribution 6.16.
# DEBUG:Node 865 acted normally with contribution 5.69.
# DEBUG:Node 866 acted normally with contribution 7.92.
# DEBUG:Node 867 acted normally with contribution 7.24.
# DEBUG:Node 868 acted normally with contribution 8.24.
# DEBUG:Node 869 acted normally with contribution 9.58.
# DEBUG:Node 870 acted normally with contribution 5.47.
# DEBUG:Node 871 acted normally with contribution 7.81.
# DEBUG:Node 872 acted normally with contribution 6.97.
# DEBUG:Node 873 acted normally with contribution 7.02.
# DEBUG:Node 874 acted normally with contribution 7.38.
# DEBUG:Node 875 acted normally with contribution 6.20.
# DEBUG:Node 876 acted normally with contribution 5.14.
# DEBUG:Node 877 acted normally with contribution 6.50.
# DEBUG:Node 878 acted normally with contribution 6.81.
# DEBUG:Node 879 acted normally with contribution 8.30.
# DEBUG:Node 880 acted normally with contribution 10.40.
# DEBUG:Node 881 acted normally with contribution 5.91.
# DEBUG:Node 882 acted normally with contribution 6.75.
# DEBUG:Node 883 acted normally with contribution 7.16.
# DEBUG:Node 884 acted normally with contribution 6.77.
# DEBUG:Node 885 acted normally with contribution 6.81.
# DEBUG:Node 886 acted normally with contribution 6.81.
# DEBUG:Node 887 acted normally with contribution 3.77.
# DEBUG:Node 888 acted normally with contribution 8.14.
# DEBUG:Node 889 acted normally with contribution 7.68.
# DEBUG:Node 890 acted normally with contribution 6.91.
# DEBUG:Node 891 acted normally with contribution 7.95.
# DEBUG:Node 892 acted normally with contribution 5.30.
# DEBUG:Node 893 acted normally with contribution 5.56.
# DEBUG:Node 894 acted normally with contribution 6.68.
# DEBUG:Node 895 acted normally with contribution 7.76.
# DEBUG:Node 896 acted normally with contribution 7.93.
# DEBUG:Node 897 acted normally with contribution 9.36.
# DEBUG:Node 898 acted normally with contribution 6.22.
# DEBUG:Node 899 acted normally with contribution 7.45.
# DEBUG:Node 900 acted normally with contribution 7.72.
# DEBUG:Node 901 acted normally with contribution 5.12.
# DEBUG:Node 902 acted normally with contribution 7.82.
# DEBUG:Node 903 acted normally with contribution 7.77.
# DEBUG:Node 904 acted normally with contribution 7.26.
# DEBUG:Node 905 acted normally with contribution 5.95.
# DEBUG:Node 906 acted normally with contribution 7.66.
# DEBUG:Node 907 acted normally with contribution 6.36.
# DEBUG:Node 908 acted normally with contribution 9.38.
# DEBUG:Node 909 acted normally with contribution 5.91.
# DEBUG:Node 910 acted normally with contribution 6.11.
# DEBUG:Node 911 acted normally with contribution 6.44.
# DEBUG:Node 912 acted normally with contribution 6.43.
# DEBUG:Node 913 acted normally with contribution 4.78.
# DEBUG:Node 914 acted normally with contribution 9.09.
# DEBUG:Node 915 acted normally with contribution 6.63.
# DEBUG:Node 916 acted normally with contribution 7.36.
# DEBUG:Node 917 acted normally with contribution 7.35.
# DEBUG:Node 918 acted normally with contribution 5.75.
# DEBUG:Node 919 acted normally with contribution 5.50.
# DEBUG:Node 920 acted normally with contribution 7.14.
# DEBUG:Node 921 acted normally with contribution 6.93.
# DEBUG:Node 922 acted normally with contribution 5.47.
# DEBUG:Node 923 acted normally with contribution 6.06.
# DEBUG:Node 924 acted normally with contribution 8.04.
# DEBUG:Node 925 acted normally with contribution 6.35.
# DEBUG:Node 926 acted normally with contribution 7.86.
# DEBUG:Node 927 acted normally with contribution 8.19.
# DEBUG:Node 928 acted normally with contribution 6.83.
# DEBUG:Node 929 acted normally with contribution 6.77.
# DEBUG:Node 930 acted normally with contribution 5.68.
# DEBUG:Node 931 acted normally with contribution 9.09.
# DEBUG:Node 932 acted normally with contribution 6.67.
# DEBUG:Node 933 acted normally with contribution 8.22.
# DEBUG:Node 934 acted normally with contribution 5.47.
# DEBUG:Node 935 acted normally with contribution 6.74.
# DEBUG:Node 936 acted normally with contribution 5.77.
# DEBUG:Node 937 acted normally with contribution 7.88.
# DEBUG:Node 938 acted normally with contribution 7.75.
# DEBUG:Node 939 acted normally with contribution 7.24.
# DEBUG:Node 940 acted normally with contribution 8.16.
# DEBUG:Node 941 acted normally with contribution 7.52.
# DEBUG:Node 942 acted normally with contribution 7.35.
# DEBUG:Node 943 acted normally with contribution 10.36.
# DEBUG:Node 944 acted normally with contribution 5.97.
# DEBUG:Node 945 acted normally with contribution 7.58.
# DEBUG:Node 946 acted normally with contribution 6.91.
# DEBUG:Node 947 acted normally with contribution 5.80.
# DEBUG:Node 948 acted normally with contribution 4.85.
# DEBUG:Node 949 acted normally with contribution 6.67.
# DEBUG:Node 950 acted normally with contribution 6.42.
# DEBUG:Node 951 acted normally with contribution 3.84.
# DEBUG:Node 952 acted normally with contribution 6.62.
# DEBUG:Node 953 acted normally with contribution 8.49.
# DEBUG:Node 954 acted normally with contribution 6.43.
# DEBUG:Node 955 acted normally with contribution 7.45.
# DEBUG:Node 956 acted normally with contribution 7.40.
# DEBUG:Node 957 acted normally with contribution 5.42.
# DEBUG:Node 958 acted normally with contribution 7.41.
# DEBUG:Node 959 acted normally with contribution 6.41.
# DEBUG:Node 960 acted normally with contribution 5.78.
# DEBUG:Node 961 acted normally with contribution 5.63.
# DEBUG:Node 962 acted normally with contribution 9.10.
# DEBUG:Node 963 acted normally with contribution 9.01.
# DEBUG:Node 964 acted normally with contribution 7.04.
# DEBUG:Node 965 acted normally with contribution 7.31.
# DEBUG:Node 966 acted normally with contribution 6.81.
# DEBUG:Node 967 acted normally with contribution 6.85.
# DEBUG:Node 968 acted normally with contribution 5.67.
# DEBUG:Node 969 acted normally with contribution 6.18.
# DEBUG:Node 970 acted normally with contribution 7.50.
# DEBUG:Node 971 acted normally with contribution 6.13.
# DEBUG:Node 972 acted normally with contribution 7.70.
# DEBUG:Node 973 acted normally with contribution 6.84.
# DEBUG:Node 974 acted normally with contribution 11.44.
# DEBUG:Node 975 acted normally with contribution 6.80.
# DEBUG:Node 976 acted normally with contribution 6.08.
# DEBUG:Node 977 acted normally with contribution 5.69.
# DEBUG:Node 978 acted normally with contribution 6.20.
# DEBUG:Node 979 acted normally with contribution 6.34.
# DEBUG:Node 980 acted normally with contribution 8.95.
# DEBUG:Node 981 acted normally with contribution 7.03.
# DEBUG:Node 982 acted normally with contribution 6.09.
# DEBUG:Node 983 acted normally with contribution 8.15.
# DEBUG:Node 984 acted normally with contribution 6.43.
# DEBUG:Node 985 acted normally with contribution 7.28.
# DEBUG:Node 986 acted normally with contribution 4.86.
# DEBUG:Node 987 acted normally with contribution 7.23.
# DEBUG:Node 988 acted normally with contribution 6.22.
# DEBUG:Node 989 acted normally with contribution 8.10.
# DEBUG:Node 990 acted normally with contribution 11.43.
# DEBUG:Node 991 acted normally with contribution 7.68.
# DEBUG:Node 992 acted normally with contribution 6.44.
# DEBUG:Node 993 acted normally with contribution 7.47.
# DEBUG:Node 994 acted normally with contribution 5.60.
# DEBUG:Node 995 acted normally with contribution 7.11.
# DEBUG:Node 996 acted normally with contribution 8.09.
# DEBUG:Node 997 acted normally with contribution 8.61.
# DEBUG:Node 998 acted normally with contribution 7.57.
# DEBUG:Node 999 acted normally with contribution 10.72.
# DEBUG:Node 1000 acted normally with contribution 5.15.
# DEBUG:Added 1 nodes to the last stratum.
# DEBUG:Final Quotas per Stratum: [2, 2, 1]
# DEBUG:Stratum 1: 333 eligible candidates.
# DEBUG:Stratum 1: Selected 2 nodes.
# DEBUG:Stratum 2: 333 eligible candidates.
# DEBUG:Stratum 2: Selected 2 nodes.
# DEBUG:Stratum 3: 334 eligible candidates.
# DEBUG:Stratum 3: Selected 1 nodes.
# DEBUG:Successfully selected 5 committee members.
# DEBUG:Node 144 selected for committee. Cooldown set to 3.
# DEBUG:Node 144 cooldown decremented to 2.
# DEBUG:Node 275 selected for committee. Cooldown set to 3.
# DEBUG:Node 275 cooldown decremented to 2.
# DEBUG:Node 614 selected for committee. Cooldown set to 3.
# DEBUG:Node 614 cooldown decremented to 2.
# DEBUG:Node 635 selected for committee. Cooldown set to 3.
# DEBUG:Node 635 cooldown decremented to 2.
# DEBUG:Node 797 selected for committee. Cooldown set to 3.
# DEBUG:Node 797 cooldown decremented to 2.
# INFO:Round 1: Committee selected with 5 members.
# DEBUG:Node 1 reputation updated to 153.93
# DEBUG:Node 1 received reward: 1.23
# DEBUG:Node 2 reputation updated to 153.14
# DEBUG:Node 2 received reward: 1.19
# DEBUG:Node 3 reputation updated to 153.56
# DEBUG:Node 3 received reward: 1.21
# DEBUG:Node 4 reputation updated to 154.10
# DEBUG:Node 4 received reward: 1.23
# DEBUG:Node 5 reputation updated to 154.56
# DEBUG:Node 5 received reward: 1.25
# DEBUG:Node 6 reputation updated to 153.75
# DEBUG:Node 6 received reward: 1.22
# DEBUG:Node 7 reputation updated to 153.91
# DEBUG:Node 7 received reward: 1.22
# DEBUG:Node 8 reputation updated to 153.10
# DEBUG:Node 8 received reward: 1.19
# DEBUG:Node 9 reputation updated to 154.29
# DEBUG:Node 9 received reward: 1.24
# DEBUG:Node 10 reputation updated to 153.31
# DEBUG:Node 10 received reward: 1.20
# DEBUG:Node 11 reputation updated to 153.61
# DEBUG:Node 11 received reward: 1.21
# DEBUG:Node 12 reputation updated to 152.88
# DEBUG:Node 12 received reward: 1.18
# DEBUG:Node 13 reputation updated to 153.51
# DEBUG:Node 13 received reward: 1.20
# DEBUG:Node 14 reputation updated to 154.30
# DEBUG:Node 14 received reward: 1.24
# DEBUG:Node 15 reputation updated to 153.65
# DEBUG:Node 15 received reward: 1.21
# DEBUG:Node 16 reputation updated to 153.55
# DEBUG:Node 16 received reward: 1.20
# DEBUG:Node 17 reputation updated to 154.55
# DEBUG:Node 17 received reward: 1.25
# DEBUG:Node 18 reputation updated to 152.88
# DEBUG:Node 18 received reward: 1.17
# DEBUG:Node 19 reputation updated to 152.88
# DEBUG:Node 19 received reward: 1.17
# DEBUG:Node 20 reputation updated to 152.88
# DEBUG:Node 20 received reward: 1.17
# DEBUG:Node 21 reputation updated to 153.58
# DEBUG:Node 21 received reward: 1.20
# DEBUG:Node 22 reputation updated to 153.60
# DEBUG:Node 22 received reward: 1.20
# DEBUG:Node 23 reputation updated to 153.88
# DEBUG:Node 23 received reward: 1.22
# DEBUG:Node 24 reputation updated to 154.03
# DEBUG:Node 24 received reward: 1.22
# DEBUG:Node 25 reputation updated to 153.81
# DEBUG:Node 25 received reward: 1.21
# DEBUG:Node 26 reputation updated to 153.23
# DEBUG:Node 26 received reward: 1.19
# DEBUG:Node 27 reputation updated to 154.34
# DEBUG:Node 27 received reward: 1.24
# DEBUG:Node 28 reputation updated to 152.88
# DEBUG:Node 28 received reward: 1.17
# DEBUG:Node 29 reputation updated to 153.13
# DEBUG:Node 29 received reward: 1.18
# DEBUG:Node 30 reputation updated to 153.57
# DEBUG:Node 30 received reward: 1.20
# DEBUG:Node 31 reputation updated to 153.05
# DEBUG:Node 31 received reward: 1.18
# DEBUG:Node 32 reputation updated to 152.88
# DEBUG:Node 32 received reward: 1.17
# DEBUG:Node 33 reputation updated to 152.88
# DEBUG:Node 33 received reward: 1.17
# DEBUG:Node 34 reputation updated to 153.64
# DEBUG:Node 34 received reward: 1.20
# DEBUG:Node 35 reputation updated to 153.06
# DEBUG:Node 35 received reward: 1.18
# DEBUG:Node 36 reputation updated to 153.74
# DEBUG:Node 36 received reward: 1.21
# DEBUG:Node 37 reputation updated to 153.59
# DEBUG:Node 37 received reward: 1.20
# DEBUG:Node 38 reputation updated to 153.30
# DEBUG:Node 38 received reward: 1.19
# DEBUG:Node 39 reputation updated to 153.54
# DEBUG:Node 39 received reward: 1.20
# DEBUG:Node 40 reputation updated to 153.27
# DEBUG:Node 40 received reward: 1.18
# DEBUG:Node 41 reputation updated to 154.33
# DEBUG:Node 41 received reward: 1.23
# DEBUG:Node 42 reputation updated to 153.41
# DEBUG:Node 42 received reward: 1.19
# DEBUG:Node 43 reputation updated to 154.59
# DEBUG:Node 43 received reward: 1.24
# DEBUG:Node 44 reputation updated to 154.62
# DEBUG:Node 44 received reward: 1.24
# DEBUG:Node 45 reputation updated to 152.88
# DEBUG:Node 45 received reward: 1.17
# DEBUG:Node 46 reputation updated to 153.96
# DEBUG:Node 46 received reward: 1.21
# DEBUG:Node 47 reputation updated to 152.88
# DEBUG:Node 47 received reward: 1.17
# DEBUG:Node 48 reputation updated to 153.86
# DEBUG:Node 48 received reward: 1.21
# DEBUG:Node 49 reputation updated to 154.97
# DEBUG:Node 49 received reward: 1.26
# DEBUG:Node 50 reputation updated to 153.77
# DEBUG:Node 50 received reward: 1.20
# DEBUG:Node 51 reputation updated to 152.99
# DEBUG:Node 51 received reward: 1.17
# DEBUG:Node 52 reputation updated to 153.14
# DEBUG:Node 52 received reward: 1.18
# DEBUG:Node 53 reputation updated to 153.55
# DEBUG:Node 53 received reward: 1.19
# DEBUG:Node 54 reputation updated to 153.69
# DEBUG:Node 54 received reward: 1.20
# DEBUG:Node 55 reputation updated to 153.34
# DEBUG:Node 55 received reward: 1.18
# DEBUG:Node 56 reputation updated to 153.58
# DEBUG:Node 56 received reward: 1.19
# DEBUG:Node 57 reputation updated to 153.34
# DEBUG:Node 57 received reward: 1.18
# DEBUG:Node 58 reputation updated to 153.63
# DEBUG:Node 58 received reward: 1.20
# DEBUG:Node 59 reputation updated to 153.82
# DEBUG:Node 59 received reward: 1.20
# DEBUG:Node 60 reputation updated to 154.17
# DEBUG:Node 60 received reward: 1.22
# DEBUG:Node 61 reputation updated to 154.18
# DEBUG:Node 61 received reward: 1.22
# DEBUG:Node 62 reputation updated to 152.88
# DEBUG:Node 62 received reward: 1.16
# DEBUG:Node 63 reputation updated to 153.88
# DEBUG:Node 63 received reward: 1.21
# DEBUG:Node 64 reputation updated to 153.24
# DEBUG:Node 64 received reward: 1.18
# DEBUG:Node 65 reputation updated to 153.64
# DEBUG:Node 65 received reward: 1.19

# %%
# =================== Simulation Report =====================
# def generate_simulation_report(system, filename):
#     """
#     Generates simulation reports for an FLSystem instance and saves them as CSV files.

#     Parameters:
#         system (FLSystem): The federated learning system instance containing simulation data.
#         filename (str): The base filename for the generated reports. The function will create
#                         two CSV files with suffixes '_round_metrics.csv' and '_node_summary.csv'.

#     Returns:
#         tuple: A tuple containing two pandas DataFrames:
#                (round_metrics_df, node_summary_df)
#     """
#     # Validate the filename extension
#     if not filename.lower().endswith('.csv'):
#         raise ValueError("Filename must end with '.csv'")
    
#     # Derive base name without extension
#     base, ext = os.path.splitext(filename)
    
#     # Define filenames for round metrics and node summary
#     round_metrics_filename = f"{base}_round_metrics.csv"
#     node_summary_filename = f"{base}_node_summary.csv"
    
#     # ------------------ Extract Per-Round Metrics ------------------
#     rounds = list(range(1, system.current_round + 1))
#     gini = system.gini_history
#     fairness = system.fairness_history
#     detected = system.detection_history
#     penalties = system.penalty_history  # List of lists
#     rewards = system.reward_history 
#     committee_history = system.committee_history  # List of lists
    
#     # Calculate total penalties per round
#     total_penalties = [sum(penalty_round) for penalty_round in penalties]
    
#     # Format committee members as comma-separated strings
#     committee_members = [', '.join(map(str, committee)) for committee in committee_history]
    
#     # Create a DataFrame for per-round metrics
#     round_metrics_df = pd.DataFrame({
#         'Round': rounds,
#         'Gini Coefficient': gini,
#         'Fairness Index': fairness,
#         'Detected Malicious Nodes': detected,
#         'Total Penalties': total_penalties,
#         'Total Rewards': rewards,
#         'Committee Members': committee_members
#     })
    
#     # ------------------ Extract Per-Node Summary Metrics ------------------
#     node_ids = [node.id for node in system.nodes]
#     stakes = [node.stake for node in system.nodes]
#     final_reputations = [node.reputation for node in system.nodes]
#     total_rewards = [node.total_reward for node in system.nodes]
#     violations = [node.violations for node in system.nodes]
#     participation = [node.participation for node in system.nodes]
#     total_committee = [node.total_committee for node in system.nodes]
#     cooldowns = [node.cooldown for node in system.nodes]
    
#     # Create a DataFrame for per-node summary
#     node_summary_df = pd.DataFrame({
#         'Node ID': node_ids,
#         'Stake': stakes,
#         'Final Reputation': final_reputations,
#         'Total Reward': total_rewards,
#         'Violations': violations,
#         'Participation Count': participation,
#         'Total Committee Memberships': total_committee,
#         'Current Cooldown': cooldowns
#     })
    
#     # ------------------ Save DataFrames to CSV Files ------------------
#     try:
#         # Save round metrics
#         round_metrics_df.to_csv(round_metrics_filename, index=False)
#         print(f"Round metrics saved to {round_metrics_filename}")
        
#         # Save node summary
#         node_summary_df.to_csv(node_summary_filename, index=False)
#         print(f"Node summary metrics saved to {node_summary_filename}")
        
#     except Exception as e:
#         print(f"Error saving simulation reports: {e}")
#         raise e
    
#     # ------------------ Return DataFrames ------------------
#     return round_metrics_df, node_summary_df

N =20
CS = 5
Base = 800
rep_exponent = 0.5
stake_weight = 0.4
R = 80
# ================== Main Program ==================
if __name__ == "__main__":
    # Set fixed random seed for reproducibility
    np.random.seed(1411758002)
    import random
    random.seed(1411758002)
    

    
    # Initialize FL Systems with different malicious ratios
    systems = {
        "with_malicious_0p10": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent= rep_exponent,
            malicious_ratio=0.1,  # 10% malicious nodes
            phase_switch_round=30,
            # Sybil resistance not considered
        ),
        "with_malicious_0p15": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.15,  # 15% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "with_malicious_0p20": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.2,  # 20% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "with_malicious_0p25": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.25,  # 25% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "with_malicious_0p30": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,  # Desired committee size
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.3,  # 30% malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False  # Sybil resistance not considered
        ),
        "without_malicious": FLSystem(
            num_nodes=N,
            base_reward=Base,
            committee_size=CS,
            stake_weight=stake_weight,
            rep_exponent=rep_exponent,
            malicious_ratio=0.0,  # No malicious nodes
            phase_switch_round=30,
            # sybil_resistance=False
        )
    }
    
    # Define the number of rounds for simulations
    rounds_with_malicious = R
    rounds_without_malicious = R

    # Run Simulations for systems with malicious nodes
    print("开始运行包含恶意节点的模拟...")
    for _ in tqdm(range(rounds_with_malicious), desc="包含恶意节点"):
        for key in ["with_malicious_0p10", "with_malicious_0p15", "with_malicious_0p20", "with_malicious_0p25", "with_malicious_0p30"]:
            systems[key].run_round()
    
    # Run Simulations for system without malicious nodes
    print("\n开始运行不包含恶意节点的模拟...")
    for _ in tqdm(range(rounds_without_malicious), desc="不包含恶意节点"):
        systems["without_malicious"].run_round()
    
    # Generate Reports
    print("\n生成模拟报告...")
    for key in systems:
        filename = f"simulation_report_{key}.csv"
        generate_simulation_report(systems[key], filename=filename)
    
    # Verify Committee Sizes
    def verify_committee_size(system, expected_size=CS):
        """
        Verify that each committee in the history meets the expected size.
        """
        for round_num, committee in enumerate(system.committee_history, 1):
            if len(committee) != expected_size:
                print(f"Round {round_num}: Committee size {len(committee)} does not match expected {expected_size}.")
        print("Verification complete.")
    
    # Verify committee sizes for all systems
    print("\n验证所有系统的委员会规模...")
    for key in systems:
        print(f"\n验证系统 '{key}' 的委员会规模...")
        verify_committee_size(systems[key], expected_size=CS)
    
    # Generate Visualization for each system
    print("\n生成系统的可视化分析图表...")
    for key in systems:
        print(key)
        label = "With Malicious Nodes" if "with_malicious" in key else "Without Malicious Nodes"
        print(f"生成系统 '{key}' 的图表...")
        plot_metrics(systems[key], label=key)
    
    print("\n所有模拟和报告生成完毕。")

# %%
def optimize_contract(lambda_val, gamma, rho, omega, vsl):
    # 计算最优贡献值
    C_star = (lambda_val / gamma) * np.exp(-omega * vsl)
    
    # 计算押金
    S_star = (gamma * C_star**2) / (2 * rho * (1 - np.exp(-omega * vsl)))
    
    # 计算奖励
    R_star = (gamma * C_star**2) / (2 * np.exp(-omega * vsl)) + rho * S_star * (np.exp(omega * vsl) - 1)
    
    return C_star, S_star, R_star

# 示例参数
lambda_val = 1.0  # 贡献单价
gamma = 0.1       # 成本系数
rho = 0.5         # 押金利用率
omega = 0.2       # 违规权重
vsl = 0.3         # 违规程度

C_opt, S_opt, R_opt = optimize_contract(lambda_val, gamma, rho, omega, vsl)
print(f"Optimal Contract: C={C_opt:.2f}, S={S_opt:.2f}, R={R_opt:.2f}")

# %%
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

# Given parameters (example values)
X_c = 10.0          # Scaling factor for contribution impact
tau_i = 5.0         # Completion time for the task
omega1 = 0.5        # Weight for violation type 1 (example)
VSL_1 = 0.2         # Normalized violation level for violation type 1 (example)
C_max = 10.0        # Normalization constant for contribution

# Compute constant A = (tau_i * exp(omega1 * VSL_1)) / X_c
A = (tau_i * np.exp(omega1 * VSL_1)) / X_c

# Define the function f(z) that we want to solve: f(z) = 0
def f(z):
    # Left-hand side: 1 - exp(-z) + z * exp(-z)
    lhs = 1 - np.exp(-z) + z * np.exp(-z)
    # Right-hand side: A / (sqrt(C_max) * sqrt(z))
    rhs = A / (np.sqrt(C_max) * np.sqrt(z))
    return lhs - rhs

# Provide an initial guess for z
z_initial = 1.0

# Solve for z using fsolve
z_solution, = fsolve(f, z_initial)
C_i_optimal = z_solution * C_max

print(f"Optimal z: {z_solution:.4f}")
print(f"Optimal Contribution C_i*: {C_i_optimal:.4f}")

# Plot f(z) to visualize the root
z_values = np.linspace(0.1, 5, 100)  # start from 0.1 to avoid division by zero
f_values = [f(z) for z in z_values]

plt.figure(figsize=(8, 4))
plt.plot(z_values, f_values, label='f(z)')
plt.axhline(0, color='red', linestyle='--')
plt.axvline(z_solution, color='green', linestyle='--', label=f'z* = {z_solution:.4f}')
plt.xlabel('z')
plt.ylabel('f(z)')
plt.title('Root Finding for Optimal z in the Contract Problem')
plt.legend()
plt.grid(True)
plt.show()
